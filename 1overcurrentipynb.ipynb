# %% [markdown]
# <a href="https://colab.research.google.com/github/marwan229/Data_Science-project/blob/main/1overcurrentipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <span style="background-color:red;
#              color:white;
#              font-size:17px;
#              text-align:center;
#              border-radius:30px 80px;
#              font-weight:bold;
#              border:2px solid red;
#              padding:0px 20px;">What are Electrical Faults?
# </span>

# %% [markdown]
# <div style="color:white;
#        display:fill;
#        border-radius:5px;
#        background-color:yellow;
#        font-size:120%;
#        font-family:Nexa;
#        style:justify;
#        font-family:'Times New Roman';
#        letter-spacing:0.5px">
#     <p style="padding: 10px;
#           color:Black;">
#          Normally, a power system operates under balanced conditions. When the system becomes unbalanced due to the failures of insulation at any point or due to the contact of live wires, a short–circuit or fault, is said to occur in the line. Faults may occur in the power system due to the number of reasons like natural disturbances (lightning, high-speed winds, earthquakes), insulation breakdown, falling of a tree, bird shorting, etc.
#     </p>
# </div>

# %% [markdown]
# <span style="background-color:red;
#              color:white;
#              font-size:17px;
#              text-align:center;
#              border-radius:30px 80px;
#              font-weight:bold;
#              border:2px solid red;
#              padding:0px 20px;">Types of Faults?
# </span>

# %% [markdown]
# <div style="color:white;
#        display:fill;
#        border-radius:5px;
#        background-color:yellow;
#        font-size:120%;
#        font-family:Nexa;
#        style:justify;
#        font-family:'Times New Roman';
#        letter-spacing:0.5px">
#     <p style="padding: 10px;
#           color:Black;">
#          Normally, a power system operates under balanced conditions. When the system becomes unbalanced due to the failures of insulation at any point or due to the contact of live wires, a short–circuit or fault, is said to occur in the line. Faults may occur in the power system due to the number of reasons like natural disturbances (lightning, high-speed winds, earthquakes), insulation breakdown, falling of a tree, bird shorting, etc.
#     </p>
# </div>

# %% [markdown]
# <span style="background-color:red;
#              color:white;
#              font-size:17px;
#              text-align:center;
#              border-radius:30px 80px;
#              font-weight:bold;
#              border:2px solid red;
#              padding:0px 20px;">Faults can be brodly categorised into two types:
# </span>

# %% [markdown]
# **1. Open-circuit Fault**
#
# **2. Short-Circuit Faults**

# %% [markdown]
# <span style="background-color:Blue;
#              color:white;
#              font-size:17px;
#              text-align:center;
#              border-radius:30px 80px;
#              font-weight:bold;
#              border:2px solid Blue;
#              padding:0px 20px;">Short-Circuit Faults
# </span>

# %% [markdown]
# **1. Symmetrical**
#
# **2. Asymmetrical Faults**

# %% [markdown]
# <span style="background-color:red;
#              color:white;
#              font-size:17px;
#              text-align:center;
#              border-radius:30px 80px;
#              font-weight:bold;
#              border:2px solid red;
#              padding:0px 20px;">Symmetrical and Asymmetrical Faults
# </span>

# %% [markdown]
# <span style="background-color:Blue;
#              color:white;
#              font-size:17px;
#              text-align:center;
#              border-radius:30px 80px;
#              font-weight:bold;
#              border:2px solid Blue;
#              padding:0px 20px;">Symmetrical Faults
# </span>

# %% [markdown]
# > * In symmetrical faults, all phases are shorted to each other or to earth (L-L-L) or (L-L-L-G).
# > * The nature of this type of fault is balanced.
# > * In this type of fault,fault currents in all phases are symmetrical i.e. their magnitudes are equal and they are equally displaced by angle 120 degree.
# > * It is more severe type of fault but it occurs rarely.

# %% [markdown]
# <span style="background-color:Blue;
#              color:white;
#              font-size:17px;
#              text-align:center;
#              border-radius:30px 80px;
#              font-weight:bold;
#              border:2px solid Blue;
#              padding:0px 20px;">Asymmetrical Faults
# </span>

# %% [markdown]
# > * These faults involve only one or two phases.
# > * In this type of fault, three phase lines become unbalanced.
# > * There are mainly three types namely line to ground (L-G), line to line (L-L) and double line to ground (LL-G) faults.
# > * These type of faults mostly occur on power system..

# %% [markdown]
# <center> <img src="https://ars.els-cdn.com/content/image/1-s2.0-S2314717217300065-gr1.jpg" width="600" height="200"> </center>

# %% [markdown]
# <span style="background-color:red;
#              color:white;
#              font-size:17px;
#              text-align:center;
#              border-radius:30px 80px;
#              font-weight:bold;
#              border:2px solid red;
#              padding:0px 20px;">About this dataset file
# </span>

# %% [markdown]
# **This file contains the dataset to classify the types of fault.**
#
# - Inputs - [Ia,Ib,Ic,Va,Vb,Vc]
#
# > Ia = Current in line A
#
# > Ib = Current in line B
#
# > Ic = Current in line C
#
#
# > Va = Voltage in line A
#
# > Vb = Voltage in line B
#
# > Vc = Voltage in line C
#
# *Examples :*
#
# - [G C B A] - Outputs
#
# - [0 0 0 0] - No Fault
#
#
# - [1 0 0 0] - Ground Fault
#
#
# - [0 0 0 1] - Fault in Line A
# - [0 0 1 0] - Fault in Line B
# - [0 1 0 0] - Fault in Line C
#
#
# - [1 0 0 1] - LG fault (Between Phase A and Ground)
# - [1 0 1 0] - LG fault (Between Phase B and Ground)
# - [1 1 0 0] - LG fault (Between Phase C and Ground)
#
#
# - [0 0 1 1] - LL fault (Between Phase B and Phase A)
# - [0 1 1 0] - LL fault (Between Phase C and Phase B)
# - [0 1 0 1] - LL fault (Between Phase C and Phase A)
#
#
# - [1 0 1 1] - LLG Fault (Between Phases A,B and Ground)
# - [1 1 0 1] - LLG Fault (Between Phases A,C and Ground)
# - [1 1 1 0] - LLG Fault (Between Phases C,B and Ground)
#
#
# - [0 1 1 1] - LLL Fault(Between all three phases)
#
#
# - [1 1 1 1] - LLLG fault( Three phase symmetrical fault)

# %% [markdown]
# <span class="label label-default" style="background-color:#DC1010; border-radius:12px; font-weight: bold; font-family:Verdana; font-size:28px; color:#FBFAFC; ">Objectives of Notebook</span>

# %% [markdown]
# <span class="label label-default" style="background-color:#DC1010; border-radius:12px; font-weight: bold; font-family:Verdana; font-size:28px; color:#FBFAFC; ">Importing Libraries:</span>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
sns.set_theme(context='notebook',
              style='white',
              palette='deep',

              font_scale=1.5,
              color_codes=True,
              rc=None)

import matplotlib

plt.rcParams['figure.figsize'] = (14,8)
plt.rcParams['figure.facecolor'] = '#F0F8FF'
plt.rcParams['figure.titlesize'] = 'medium'
plt.rcParams['figure.dpi'] = 150
plt.rcParams['figure.edgecolor'] = 'green'
plt.rcParams['figure.frameon'] = True

plt.rcParams["figure.autolayout"] = True

plt.rcParams['axes.facecolor'] = '#F5F5DC'
plt.rcParams['axes.titlesize'] = 25
plt.rcParams["axes.titleweight"] = 'normal'
plt.rcParams["axes.titlecolor"] = 'Olive'
plt.rcParams['axes.edgecolor'] = 'pink'

plt.rcParams["axes.linewidth"] = 2
plt.rcParams["axes.grid"] = True
plt.rcParams['axes.titlelocation'] = 'center'
plt.rcParams["axes.labelsize"] = 20
plt.rcParams["axes.labelpad"] = 2
plt.rcParams['axes.labelweight'] = 1
plt.rcParams["axes.labelcolor"] = 'Olive'
plt.rcParams["axes.axisbelow"] = False
plt.rcParams['axes.xmargin'] = .2
plt.rcParams["axes.ymargin"] = .2

plt.rcParams["xtick.bottom"] = True
plt.rcParams['xtick.color'] = '#A52A2A'
plt.rcParams["ytick.left"] = True
plt.rcParams['ytick.color'] = '#A52A2A'

plt.rcParams['axes.grid'] = True
plt.rcParams['grid.color'] = 'green'
plt.rcParams['grid.linestyle'] = '--'
plt.rcParams['grid.linewidth'] = .5
plt.rcParams['grid.alpha'] = .3

plt.rcParams['legend.loc'] = 'best'
plt.rcParams['legend.facecolor'] =  'NavajoWhite'
plt.rcParams['legend.edgecolor'] = 'pink'
plt.rcParams['legend.shadow'] = True
plt.rcParams['legend.fontsize'] = 20



plt.rcParams['font.size'] = 14

plt.rcParams['figure.dpi'] = 150
plt.rcParams['figure.edgecolor'] = 'Blue'

# %%
df_class = pd.read_csv("/content/classData.csv")
df_class.sample(5).style.set_properties(**{'background-color': 'blue',
                           'color': 'white',
                           'border-color': 'darkblack'})
# Out:
# <style type="text/css">
# #T_b6021_row0_col0, #T_b6021_row0_col1, #T_b6021_row0_col2, #T_b6021_row0_col3, #T_b6021_row0_col4, #T_b6021_row0_col5, #T_b6021_row0_col6, #T_b6021_row1_col0, #T_b6021_row1_col1, #T_b6021_row1_col2, #T_b6021_row1_col3, #T_b6021_row1_col4, #T_b6021_row1_col5, #T_b6021_row1_col6, #T_b6021_row2_col0, #T_b6021_row2_col1, #T_b6021_row2_col2, #T_b6021_row2_col3, #T_b6021_row2_col4, #T_b6021_row2_col5, #T_b6021_row2_col6, #T_b6021_row3_col0, #T_b6021_row3_col1, #T_b6021_row3_col2, #T_b6021_row3_col3, #T_b6021_row3_col4, #T_b6021_row3_col5, #T_b6021_row3_col6, #T_b6021_row4_col0, #T_b6021_row4_col1, #T_b6021_row4_col2, #T_b6021_row4_col3, #T_b6021_row4_col4, #T_b6021_row4_col5, #T_b6021_row4_col6 {
#   background-color: blue;
#   color: white;
#   border-color: darkblack;
# }
# </style>
# <table id="T_b6021" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b6021_level0_col0" class="col_heading level0 col0" >Ia</th>
#       <th id="T_b6021_level0_col1" class="col_heading level0 col1" >Ib</th>
#       <th id="T_b6021_level0_col2" class="col_heading level0 col2" >Ic</th>
#       <th id="T_b6021_level0_col3" class="col_heading level0 col3" >G</th>
#       <th id="T_b6021_level0_col4" class="col_heading level0 col4" >C</th>
#       <th id="T_b6021_level0_col5" class="col_heading level0 col5" >B</th>
#       <th id="T_b6021_level0_col6" class="col_heading level0 col6" >A</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b6021_level0_row0" class="row_heading level0 row0" >1843</th>
#       <td id="T_b6021_row0_col0" class="data row0 col0" >60.895260</td>
#       <td id="T_b6021_row0_col1" class="data row0 col1" >-69.339501</td>
#       <td id="T_b6021_row0_col2" class="data row0 col2" >8.444242</td>
#       <td id="T_b6021_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_b6021_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_b6021_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_b6021_row0_col6" class="data row0 col6" >0</td>
#     </tr>
#     <tr>
#       <th id="T_b6021_level0_row1" class="row_heading level0 row1" >856</th>
#       <td id="T_b6021_row1_col0" class="data row1 col0" >-3.171838</td>
#       <td id="T_b6021_row1_col1" class="data row1 col1" >5.828977</td>
#       <td id="T_b6021_row1_col2" class="data row1 col2" >-2.657138</td>
#       <td id="T_b6021_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_b6021_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_b6021_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_b6021_row1_col6" class="data row1 col6" >0</td>
#     </tr>
#     <tr>
#       <th id="T_b6021_level0_row2" class="row_heading level0 row2" >226</th>
#       <td id="T_b6021_row2_col0" class="data row2 col0" >-689.362058</td>
#       <td id="T_b6021_row2_col1" class="data row2 col1" >-118.658924</td>
#       <td id="T_b6021_row2_col2" class="data row2 col2" >-39.696951</td>
#       <td id="T_b6021_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_b6021_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_b6021_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_b6021_row2_col6" class="data row2 col6" >1</td>
#     </tr>
#     <tr>
#       <th id="T_b6021_level0_row3" class="row_heading level0 row3" >1232</th>
#       <td id="T_b6021_row3_col0" class="data row3 col0" >-39.915220</td>
#       <td id="T_b6021_row3_col1" class="data row3 col1" >21.880176</td>
#       <td id="T_b6021_row3_col2" class="data row3 col2" >18.035207</td>
#       <td id="T_b6021_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_b6021_row3_col4" class="data row3 col4" >1</td>
#       <td id="T_b6021_row3_col5" class="data row3 col5" >1</td>
#       <td id="T_b6021_row3_col6" class="data row3 col6" >0</td>
#     </tr>
#     <tr>
#       <th id="T_b6021_level0_row4" class="row_heading level0 row4" >1780</th>
#       <td id="T_b6021_row4_col0" class="data row4 col0" >-25711.202270</td>
#       <td id="T_b6021_row4_col1" class="data row4 col1" >5.079434</td>
#       <td id="T_b6021_row4_col2" class="data row4 col2" >25706.122840</td>
#       <td id="T_b6021_row4_col3" class="data row4 col3" >1</td>
#       <td id="T_b6021_row4_col4" class="data row4 col4" >1</td>
#       <td id="T_b6021_row4_col5" class="data row4 col5" >1</td>
#       <td id="T_b6021_row4_col6" class="data row4 col6" >1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <span style="background-color:red;
#              color:white;
#              font-size:17px;
#              text-align:center;
#              border-radius:30px 80px;
#              font-weight:bold;
#              border:2px solid red;
#              padding:0px 20px;">Voltage is in Per Unit value (pu)
# </span>

# %%
df_class.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1859 entries, 0 to 1858
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Ia      1859 non-null   float64
#  1   Ib      1859 non-null   float64
#  2   Ic      1859 non-null   float64
#  3   G       1859 non-null   int64
#  4   C       1859 non-null   int64
#  5   B       1859 non-null   int64
#  6   A       1859 non-null   int64
# dtypes: float64(3), int64(4)
# memory usage: 101.8 KB

# %%
df_class.isnull().sum().sum()
# Out:
# 0

# %%
df_class.shape
# Out:
# (1859, 7)

# %%
ax = plt.subplot(1,2,1)
ax = sns.countplot(x='G', data=df_class)
ax.bar_label(ax.containers[0])
plt.title("Ground Fault", fontsize=20,color = 'Brown',pad=20)

ax =plt.subplot(1,2,2)
ax=df_class['G'].value_counts().plot.pie(explode=[0.1, 0.1],autopct='%1.2f%%',shadow=True);
ax.set_title(label = "Ground Fault", fontsize = 20,color='Brown',pad=20);

# %%
ax = plt.subplot(1,2,1)
ax = sns.countplot(x='A', data=df_class)
ax.bar_label(ax.containers[0])
plt.title("Line A Fault", fontsize=20,color = 'Brown',pad=20)

ax =plt.subplot(1,2,2)
ax=df_class['A'].value_counts().plot.pie(explode=[0.1, 0.1],autopct='%1.2f%%',shadow=True);
ax.set_title(label = "Line A Fault", fontsize = 20,color='Brown',pad=20);

# %%
ax = plt.subplot(1,2,1)
ax = sns.countplot(x='B', data=df_class)
ax.bar_label(ax.containers[0])
plt.title("Line B Fault", fontsize=20,color = 'Brown',pad=20)

ax =plt.subplot(1,2,2)
ax=df_class['B'].value_counts().plot.pie(explode=[0.1, 0.1],autopct='%1.2f%%',shadow=True);
ax.set_title(label = "Line B Fault", fontsize = 20,color='Brown',pad=20);

# %%
ax = plt.subplot(1,2,1)
ax = sns.countplot(x='C', data=df_class)
ax.bar_label(ax.containers[0])
plt.title("Line C Fault", fontsize=20,color = 'Brown',pad=20)

ax =plt.subplot(1,2,2)
ax=df_class['C'].value_counts().plot.pie(explode=[0.1, 0.1],autopct='%1.2f%%',shadow=True);
ax.set_title(label = "Line C Fault", fontsize = 20,color='Brown',pad=20);

# %% [markdown]
# <span style="background-color:red;
#              color:white;
#              font-size:17px;
#              text-align:center;
#              border-radius:30px 80px;
#              font-weight:bold;
#              border:2px solid red;
#              padding:0px 20px;">Combing all fault together in one Fault_Type
# </span>

# %%
df_class['Fault_Type'] = df_class['G'].astype('str') + df_class['C'].astype('str') + df_class['B'].astype('str') + df_class['A'].astype('str')
df_class.head().style.set_properties(**{'background-color': 'blue',
                           'color': 'white',
                           'border-color': 'darkblack'})
# Out:
# <style type="text/css">
# #T_d82d1_row0_col0, #T_d82d1_row0_col1, #T_d82d1_row0_col2, #T_d82d1_row0_col3, #T_d82d1_row0_col4, #T_d82d1_row0_col5, #T_d82d1_row0_col6, #T_d82d1_row0_col7, #T_d82d1_row1_col0, #T_d82d1_row1_col1, #T_d82d1_row1_col2, #T_d82d1_row1_col3, #T_d82d1_row1_col4, #T_d82d1_row1_col5, #T_d82d1_row1_col6, #T_d82d1_row1_col7, #T_d82d1_row2_col0, #T_d82d1_row2_col1, #T_d82d1_row2_col2, #T_d82d1_row2_col3, #T_d82d1_row2_col4, #T_d82d1_row2_col5, #T_d82d1_row2_col6, #T_d82d1_row2_col7, #T_d82d1_row3_col0, #T_d82d1_row3_col1, #T_d82d1_row3_col2, #T_d82d1_row3_col3, #T_d82d1_row3_col4, #T_d82d1_row3_col5, #T_d82d1_row3_col6, #T_d82d1_row3_col7, #T_d82d1_row4_col0, #T_d82d1_row4_col1, #T_d82d1_row4_col2, #T_d82d1_row4_col3, #T_d82d1_row4_col4, #T_d82d1_row4_col5, #T_d82d1_row4_col6, #T_d82d1_row4_col7 {
#   background-color: blue;
#   color: white;
#   border-color: darkblack;
# }
# </style>
# <table id="T_d82d1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d82d1_level0_col0" class="col_heading level0 col0" >Ia</th>
#       <th id="T_d82d1_level0_col1" class="col_heading level0 col1" >Ib</th>
#       <th id="T_d82d1_level0_col2" class="col_heading level0 col2" >Ic</th>
#       <th id="T_d82d1_level0_col3" class="col_heading level0 col3" >G</th>
#       <th id="T_d82d1_level0_col4" class="col_heading level0 col4" >C</th>
#       <th id="T_d82d1_level0_col5" class="col_heading level0 col5" >B</th>
#       <th id="T_d82d1_level0_col6" class="col_heading level0 col6" >A</th>
#       <th id="T_d82d1_level0_col7" class="col_heading level0 col7" >Fault_Type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d82d1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d82d1_row0_col0" class="data row0 col0" >0.096536</td>
#       <td id="T_d82d1_row0_col1" class="data row0 col1" >-3.626482</td>
#       <td id="T_d82d1_row0_col2" class="data row0 col2" >3.529946</td>
#       <td id="T_d82d1_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_d82d1_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_d82d1_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_d82d1_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_d82d1_row0_col7" class="data row0 col7" >0000</td>
#     </tr>
#     <tr>
#       <th id="T_d82d1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d82d1_row1_col0" class="data row1 col0" >0.244247</td>
#       <td id="T_d82d1_row1_col1" class="data row1 col1" >-5.771591</td>
#       <td id="T_d82d1_row1_col2" class="data row1 col2" >5.527344</td>
#       <td id="T_d82d1_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_d82d1_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_d82d1_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_d82d1_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_d82d1_row1_col7" class="data row1 col7" >0000</td>
#     </tr>
#     <tr>
#       <th id="T_d82d1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d82d1_row2_col0" class="data row2 col0" >0.457486</td>
#       <td id="T_d82d1_row2_col1" class="data row2 col1" >-7.902264</td>
#       <td id="T_d82d1_row2_col2" class="data row2 col2" >7.444778</td>
#       <td id="T_d82d1_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_d82d1_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_d82d1_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_d82d1_row2_col6" class="data row2 col6" >0</td>
#       <td id="T_d82d1_row2_col7" class="data row2 col7" >0000</td>
#     </tr>
#     <tr>
#       <th id="T_d82d1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d82d1_row3_col0" class="data row3 col0" >0.734731</td>
#       <td id="T_d82d1_row3_col1" class="data row3 col1" >-10.017085</td>
#       <td id="T_d82d1_row3_col2" class="data row3 col2" >9.282354</td>
#       <td id="T_d82d1_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_d82d1_row3_col4" class="data row3 col4" >0</td>
#       <td id="T_d82d1_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_d82d1_row3_col6" class="data row3 col6" >0</td>
#       <td id="T_d82d1_row3_col7" class="data row3 col7" >0000</td>
#     </tr>
#     <tr>
#       <th id="T_d82d1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d82d1_row4_col0" class="data row4 col0" >1.074442</td>
#       <td id="T_d82d1_row4_col1" class="data row4 col1" >-12.114648</td>
#       <td id="T_d82d1_row4_col2" class="data row4 col2" >11.040206</td>
#       <td id="T_d82d1_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_d82d1_row4_col4" class="data row4 col4" >0</td>
#       <td id="T_d82d1_row4_col5" class="data row4 col5" >0</td>
#       <td id="T_d82d1_row4_col6" class="data row4 col6" >0</td>
#       <td id="T_d82d1_row4_col7" class="data row4 col7" >0000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <span style="background-color:red;
#              color:white;
#              font-size:17px;
#              text-align:center;
#              border-radius:30px 80px;
#              font-weight:bold;
#              border:2px solid red;
#              padding:0px 20px;">Giving the proper name to the fault according to the data description provided above
# </span>

# %%
df_class['Fault_Type'][df_class['Fault_Type'] == '0000' ] = 'NO Fault'
df_class['Fault_Type'][df_class['Fault_Type'] == '0001' ] = 'Line A Fault'
df_class['Fault_Type'][df_class['Fault_Type'] == '0010' ] = 'Line B Fault'
df_class['Fault_Type'][df_class['Fault_Type'] == '0100' ] = 'Line C Fault'
df_class['Fault_Type'][df_class['Fault_Type'] == '1001' ] = 'Line A to Ground Fault'
df_class['Fault_Type'][df_class['Fault_Type'] == '1010' ] = 'Line B to Ground Fault'
df_class['Fault_Type'][df_class['Fault_Type'] == '1100' ] = 'Line C to Ground Fault'
df_class['Fault_Type'][df_class['Fault_Type'] == '1011' ] = 'Line A Line B to Ground Fault'
df_class['Fault_Type'][df_class['Fault_Type'] == '1101' ] = 'Line A Line C to Ground Fault'
df_class['Fault_Type'][df_class['Fault_Type'] == '1110' ] = 'Line B Line C to Ground Fault'
df_class['Fault_Type'][df_class['Fault_Type'] == '0011' ] = 'Line A to Line B fault'
df_class['Fault_Type'][df_class['Fault_Type'] == '0101' ] = 'Line A to Line C Fault'
df_class['Fault_Type'][df_class['Fault_Type'] == '0110' ] = 'Line B to Line C Fault'
df_class['Fault_Type'][df_class['Fault_Type'] == '0111' ] = 'Line A Line B Line C'
df_class['Fault_Type'][df_class['Fault_Type'] == '1111' ] = 'Line A Line B Line C to Ground Fault'

# %%
df_class.sample(10).style.set_properties(**{'background-color': 'blue',
                           'color': 'white',
                           'border-color': 'darkblack'})
# Out:
# <style type="text/css">
# #T_53b95_row0_col0, #T_53b95_row0_col1, #T_53b95_row0_col2, #T_53b95_row0_col3, #T_53b95_row0_col4, #T_53b95_row0_col5, #T_53b95_row0_col6, #T_53b95_row0_col7, #T_53b95_row1_col0, #T_53b95_row1_col1, #T_53b95_row1_col2, #T_53b95_row1_col3, #T_53b95_row1_col4, #T_53b95_row1_col5, #T_53b95_row1_col6, #T_53b95_row1_col7, #T_53b95_row2_col0, #T_53b95_row2_col1, #T_53b95_row2_col2, #T_53b95_row2_col3, #T_53b95_row2_col4, #T_53b95_row2_col5, #T_53b95_row2_col6, #T_53b95_row2_col7, #T_53b95_row3_col0, #T_53b95_row3_col1, #T_53b95_row3_col2, #T_53b95_row3_col3, #T_53b95_row3_col4, #T_53b95_row3_col5, #T_53b95_row3_col6, #T_53b95_row3_col7, #T_53b95_row4_col0, #T_53b95_row4_col1, #T_53b95_row4_col2, #T_53b95_row4_col3, #T_53b95_row4_col4, #T_53b95_row4_col5, #T_53b95_row4_col6, #T_53b95_row4_col7, #T_53b95_row5_col0, #T_53b95_row5_col1, #T_53b95_row5_col2, #T_53b95_row5_col3, #T_53b95_row5_col4, #T_53b95_row5_col5, #T_53b95_row5_col6, #T_53b95_row5_col7, #T_53b95_row6_col0, #T_53b95_row6_col1, #T_53b95_row6_col2, #T_53b95_row6_col3, #T_53b95_row6_col4, #T_53b95_row6_col5, #T_53b95_row6_col6, #T_53b95_row6_col7, #T_53b95_row7_col0, #T_53b95_row7_col1, #T_53b95_row7_col2, #T_53b95_row7_col3, #T_53b95_row7_col4, #T_53b95_row7_col5, #T_53b95_row7_col6, #T_53b95_row7_col7, #T_53b95_row8_col0, #T_53b95_row8_col1, #T_53b95_row8_col2, #T_53b95_row8_col3, #T_53b95_row8_col4, #T_53b95_row8_col5, #T_53b95_row8_col6, #T_53b95_row8_col7, #T_53b95_row9_col0, #T_53b95_row9_col1, #T_53b95_row9_col2, #T_53b95_row9_col3, #T_53b95_row9_col4, #T_53b95_row9_col5, #T_53b95_row9_col6, #T_53b95_row9_col7 {
#   background-color: blue;
#   color: white;
#   border-color: darkblack;
# }
# </style>
# <table id="T_53b95" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_53b95_level0_col0" class="col_heading level0 col0" >Ia</th>
#       <th id="T_53b95_level0_col1" class="col_heading level0 col1" >Ib</th>
#       <th id="T_53b95_level0_col2" class="col_heading level0 col2" >Ic</th>
#       <th id="T_53b95_level0_col3" class="col_heading level0 col3" >G</th>
#       <th id="T_53b95_level0_col4" class="col_heading level0 col4" >C</th>
#       <th id="T_53b95_level0_col5" class="col_heading level0 col5" >B</th>
#       <th id="T_53b95_level0_col6" class="col_heading level0 col6" >A</th>
#       <th id="T_53b95_level0_col7" class="col_heading level0 col7" >Fault_Type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_53b95_level0_row0" class="row_heading level0 row0" >252</th>
#       <td id="T_53b95_row0_col0" class="data row0 col0" >-713.655640</td>
#       <td id="T_53b95_row0_col1" class="data row0 col1" >-37.541927</td>
#       <td id="T_53b95_row0_col2" class="data row0 col2" >4.589313</td>
#       <td id="T_53b95_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_53b95_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_53b95_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_53b95_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_53b95_row0_col7" class="data row0 col7" >Line A to Ground Fault</td>
#     </tr>
#     <tr>
#       <th id="T_53b95_level0_row1" class="row_heading level0 row1" >838</th>
#       <td id="T_53b95_row1_col0" class="data row1 col0" >5.054597</td>
#       <td id="T_53b95_row1_col1" class="data row1 col1" >-5.054597</td>
#       <td id="T_53b95_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_53b95_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_53b95_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_53b95_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_53b95_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_53b95_row1_col7" class="data row1 col7" >Line B Fault</td>
#     </tr>
#     <tr>
#       <th id="T_53b95_level0_row2" class="row_heading level0 row2" >1130</th>
#       <td id="T_53b95_row2_col0" class="data row2 col0" >21.108917</td>
#       <td id="T_53b95_row2_col1" class="data row2 col1" >-46.262751</td>
#       <td id="T_53b95_row2_col2" class="data row2 col2" >25.153997</td>
#       <td id="T_53b95_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_53b95_row2_col4" class="data row2 col4" >1</td>
#       <td id="T_53b95_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_53b95_row2_col6" class="data row2 col6" >1</td>
#       <td id="T_53b95_row2_col7" class="data row2 col7" >Line A to Line C Fault</td>
#     </tr>
#     <tr>
#       <th id="T_53b95_level0_row3" class="row_heading level0 row3" >153</th>
#       <td id="T_53b95_row3_col0" class="data row3 col0" >5.317367</td>
#       <td id="T_53b95_row3_col1" class="data row3 col1" >0.260536</td>
#       <td id="T_53b95_row3_col2" class="data row3 col2" >-5.577903</td>
#       <td id="T_53b95_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_53b95_row3_col4" class="data row3 col4" >0</td>
#       <td id="T_53b95_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_53b95_row3_col6" class="data row3 col6" >0</td>
#       <td id="T_53b95_row3_col7" class="data row3 col7" >NO Fault</td>
#     </tr>
#     <tr>
#       <th id="T_53b95_level0_row4" class="row_heading level0 row4" >679</th>
#       <td id="T_53b95_row4_col0" class="data row4 col0" >263.799205</td>
#       <td id="T_53b95_row4_col1" class="data row4 col1" >61.149136</td>
#       <td id="T_53b95_row4_col2" class="data row4 col2" >-47.061152</td>
#       <td id="T_53b95_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_53b95_row4_col4" class="data row4 col4" >0</td>
#       <td id="T_53b95_row4_col5" class="data row4 col5" >0</td>
#       <td id="T_53b95_row4_col6" class="data row4 col6" >1</td>
#       <td id="T_53b95_row4_col7" class="data row4 col7" >Line A Fault</td>
#     </tr>
#     <tr>
#       <th id="T_53b95_level0_row5" class="row_heading level0 row5" >453</th>
#       <td id="T_53b95_row5_col0" class="data row5 col0" >-11.794016</td>
#       <td id="T_53b95_row5_col1" class="data row5 col1" >-9951.569651</td>
#       <td id="T_53b95_row5_col2" class="data row5 col2" >15.323222</td>
#       <td id="T_53b95_row5_col3" class="data row5 col3" >1</td>
#       <td id="T_53b95_row5_col4" class="data row5 col4" >0</td>
#       <td id="T_53b95_row5_col5" class="data row5 col5" >1</td>
#       <td id="T_53b95_row5_col6" class="data row5 col6" >0</td>
#       <td id="T_53b95_row5_col7" class="data row5 col7" >Line B to Ground Fault</td>
#     </tr>
#     <tr>
#       <th id="T_53b95_level0_row6" class="row_heading level0 row6" >332</th>
#       <td id="T_53b95_row6_col0" class="data row6 col0" >10314.009440</td>
#       <td id="T_53b95_row6_col1" class="data row6 col1" >-2.013439</td>
#       <td id="T_53b95_row6_col2" class="data row6 col2" >10.830349</td>
#       <td id="T_53b95_row6_col3" class="data row6 col3" >1</td>
#       <td id="T_53b95_row6_col4" class="data row6 col4" >0</td>
#       <td id="T_53b95_row6_col5" class="data row6 col5" >0</td>
#       <td id="T_53b95_row6_col6" class="data row6 col6" >1</td>
#       <td id="T_53b95_row6_col7" class="data row6 col7" >Line A to Ground Fault</td>
#     </tr>
#     <tr>
#       <th id="T_53b95_level0_row7" class="row_heading level0 row7" >400</th>
#       <td id="T_53b95_row7_col0" class="data row7 col0" >-17.331326</td>
#       <td id="T_53b95_row7_col1" class="data row7 col1" >-10317.060410</td>
#       <td id="T_53b95_row7_col2" class="data row7 col2" >9.891788</td>
#       <td id="T_53b95_row7_col3" class="data row7 col3" >1</td>
#       <td id="T_53b95_row7_col4" class="data row7 col4" >0</td>
#       <td id="T_53b95_row7_col5" class="data row7 col5" >1</td>
#       <td id="T_53b95_row7_col6" class="data row7 col6" >0</td>
#       <td id="T_53b95_row7_col7" class="data row7 col7" >Line B to Ground Fault</td>
#     </tr>
#     <tr>
#       <th id="T_53b95_level0_row8" class="row_heading level0 row8" >1042</th>
#       <td id="T_53b95_row8_col0" class="data row8 col0" >711.369585</td>
#       <td id="T_53b95_row8_col1" class="data row8 col1" >-754.496378</td>
#       <td id="T_53b95_row8_col2" class="data row8 col2" >43.126630</td>
#       <td id="T_53b95_row8_col3" class="d

# %%
df_class['Fault_Type'].value_counts(ascending=False)
# Out:
# Fault_Type
# NO Fault                                252
# Line C to Ground Fault                  157
# Line B Fault                            145
# Line A to Ground Fault                  142
# Line A Line B Line C to Ground Fault    131
# Line B to Line C Fault                  114
# Line B to Ground Fault                  113
# Line A Line C to Ground Fault           110
# Line A Line B Line C                    106
# Line B Line C to Ground Fault           102
# Line A to Line C Fault                  101
# Line A Fault                            100
# Line C Fault                             98
# Line A to Line B fault                   95
# Line A Line B to Ground Fault            93
# Name: count, dtype: int64

# %% [markdown]
# <h1 style="background-color:black
# ;font-family:newtimeroman;font-size:350%;text-align:center;border-radius: 150px 150px; color:#40E0D0">Feature and Label seperation </h1><a id=0></a>

# %% [markdown]
# <span style="background-color:pink;
#              color:Blue;
#              font-size:25px;
#              text-align:center;
#              border-radius:50px 80px;
#              font-weight:bold;
#              border:2px solid red;
#              padding:0px 20px;"> Categorical to Numerical conversion
# </span>

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
df_class['Fault_Type'] = encoder.fit_transform(df_class['Fault_Type'])
df_class.head()
# Out:
#          Ia         Ib         Ic  G  C  B  A  Fault_Type
# 0  0.096536  -3.626482   3.529946  0  0  0  0          14
# 1  0.244247  -5.771591   5.527344  0  0  0  0          14
# 2  0.457486  -7.902264   7.444778  0  0  0  0          14
# 3  0.734731 -10.017085   9.282354  0  0  0  0          14
# 4  1.074442 -12.114648  11.040206  0  0  0  0          14

# %% [markdown]
# <span style="background-color:pink;
#              color:Blue;
#              font-size:25px;
#              text-align:center;
#              border-radius:50px 80px;
#              font-weight:bold;
#              border:2px solid red;
#              padding:0px 20px;"> Dependent and Independent Variable Sepration
# </span>

# %%
X = df_class.drop(['Fault_Type'],axis=1)
y = df_class['Fault_Type']

# %% [markdown]
# <span style="background-color:pink;
#              color:Blue;
#              font-size:25px;
#              text-align:center;
#              border-radius:50px 80px;
#              font-weight:bold;
#              border:2px solid red;
#              padding:0px 20px;"> Train Test Split
# </span>

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=.20,random_state=21)

# %% [markdown]
# <h1 style="background-color:black
# ;font-family:newtimeroman;font-size:350%;text-align:center;border-radius: 150px 150px; color:#40E0D0"> Model Selection </h1><a id=0></a>

# %% [markdown]
# <div style="display:fill;
#             border-radius:15px;
#             background-color:cyan;
#             font-size:210%;
#             font-family:Vardana;
#             letter-spacing:0.5px;
#             padding:10px;
#             color:Brown;
#             border-style: solid;
#             border-color: red;
#             text-align:Left;">
# <b>Logistic Regression</b>
# </div>

# %%
pip show scikit-learn
# Out:
# Name: scikit-learn
# Version: 1.2.2
# Summary: A set of python modules for machine learning and data mining
# Home-page: http://scikit-learn.org
# Author:
# Author-email:
# License: new BSD
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: joblib, numpy, scipy, threadpoolctl
# Required-by: bigframes, fastai, imbalanced-learn, librosa, mlxtend, qudida, sklearn-pandas, yellowbrick

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# Logistic Regression
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
y_pred_lr = logreg.predict(X_test)

log_train = round(logreg.score(X_train, y_train) * 100, 2)
log_accuracy = round(accuracy_score(y_pred_lr, y_test) * 100, 2)


print("Training Accuracy    :",log_train ,"%")
print("Model Accuracy Score :",log_accuracy ,"%")
print("\033[1m--------------------------------------------------------\033[0m")
print("Classification_Report: \n",classification_report(y_test,y_pred_lr))
print("\033[1m--------------------------------------------------------\033[0m")
# Out:
# Training Accuracy    : 64.69 %
# Model Accuracy Score : 63.44 %
# --------------------------------------------------------
# Classification_Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        27
#            1       1.00      0.65      0.79        17
#            2       0.89      0.89      0.89        35
#            3       1.00      0.21      0.35        14
#            4       0.00      0.00      0.00        20
#            5       0.46      1.00      0.63        33
#            6       1.00      0.53      0.70        15
#            7       0.67      0.24      0.35        17
#            8       0.78      1.00      0.88        25
#            9       0.33      0.08      0.12        26
#           10       1.00      0.95      0.97        20
#           11       1.00      0.86      0.92        21
#           12       0.00      0.00      0.00        20
#           13       0.26      1.00      0.41        28
#           14       1.00      1.00      1.00        54
#
#     accuracy                           0.63       372
#    macro avg       0.63      0.56      0.53       372
# weighted avg       0.63      0.63      0.58       372
#
# --------------------------------------------------------

# %% [markdown]
# <div style="display:fill;
#             border-radius:15px;
#             background-color:cyan;
#             font-size:210%;
#             font-family:Vardana;
#             letter-spacing:0.5px;
#             padding:10px;
#             color:Brown;
#             border-style: solid;
#             border-color: red;
#             text-align:Left;">
# <b>Decision Tree Classifier</b>
# </div>

# %%
# Decision Tree
from sklearn.tree import DecisionTreeClassifier
decision = DecisionTreeClassifier()
decision.fit(X_train, y_train)
y_pred_dec = decision.predict(X_test)

decision_train = round(decision.score(X_train, y_train) * 100, 2)
decision_accuracy = round(accuracy_score(y_pred_dec, y_test) * 100, 2)

print("Training Accuracy    :",decision_train ,"%")
print("Model Accuracy Score :",decision_accuracy ,"%")
print("\033[1m--------------------------------------------------------\033[0m")
print("Classification_Report: \n",classification_report(y_test,y_pred_dec))
print("\033[1m--------------------------------------------------------\033[0m")
# Out:
# Training Accuracy    : 100.0 %
# Model Accuracy Score : 100.0 %
# --------------------------------------------------------
# Classification_Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        27
#            1       1.00      1.00      1.00        17
#            2       1.00      1.00      1.00        35
#            3       1.00      1.00      1.00        14
#            4       1.00      1.00      1.00        20
#            5       1.00      1.00      1.00        33
#            6       1.00      1.00      1.00        15
#            7       1.00      1.00      1.00        17
#            8       1.00      1.00      1.00        25
#            9       1.00      1.00      1.00        26
#           10       1.00      1.00      1.00        20
#           11       1.00      1.00      1.00        21
#           12       1.00      1.00      1.00        20
#           13       1.00      1.00      1.00        28
#           14       1.00      1.00      1.00        54
#
#     accuracy                           1.00       372
#    macro avg       1.00      1.00      1.00       372
# weighted avg       1.00      1.00      1.00       372
#
# --------------------------------------------------------

# %% [markdown]
# <div style="display:fill;
#             border-radius:15px;
#             background-color:cyan;
#             font-size:210%;
#             font-family:Vardana;
#             letter-spacing:0.5px;
#             padding:10px;
#             color:Brown;
#             border-style: solid;
#             border-color: red;
#             text-align:Left;">
# <b>Random Forest Classifier</b>
# </div>

# %%
# Random Forest
from sklearn.ensemble import RandomForestClassifier
random_forest = RandomForestClassifier(n_estimators=100)
random_forest.fit(X_train, y_train)
y_pred_rf = random_forest.predict(X_test)
random_forest.score(X_train, y_train)

random_forest_train = round(random_forest.score(X_train, y_train) * 100, 2)
random_forest_accuracy = round(accuracy_score(y_pred_rf, y_test) * 100, 2)

print("Training Accuracy    :",random_forest_train ,"%")
print("Model Accuracy Score :",random_forest_accuracy ,"%")
print("\033[1m--------------------------------------------------------\033[0m")
print("Classification_Report: \n",classification_report(y_test,y_pred_rf))
print("\033[1m--------------------------------------------------------\033[0m")
# Out:
# Training Accuracy    : 100.0 %
# Model Accuracy Score : 100.0 %
# --------------------------------------------------------
# Classification_Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        27
#            1       1.00      1.00      1.00        17
#            2       1.00      1.00      1.00        35
#            3       1.00      1.00      1.00        14
#            4       1.00      1.00      1.00        20
#            5       1.00      1.00      1.00        33
#            6       1.00      1.00      1.00        15
#            7       1.00      1.00      1.00        17
#            8       1.00      1.00      1.00        25
#            9       1.00      1.00      1.00        26
#           10       1.00      1.00      1.00        20
#           11       1.00      1.00      1.00        21
#           12       1.00      1.00      1.00        20
#           13       1.00      1.00      1.00        28
#           14       1.00      1.00      1.00        54
#
#     accuracy                           1.00       372
#    macro avg       1.00      1.00      1.00       372
# weighted avg       1.00      1.00      1.00       372
#
# --------------------------------------------------------

# %% [markdown]
# <div style="display:fill;
#             border-radius:15px;
#             background-color:cyan;
#             font-size:210%;
#             font-family:Vardana;
#             letter-spacing:0.5px;
#             padding:10px;
#             color:Brown;
#             border-style: solid;
#             border-color: red;
#             text-align:Left;">
# <b>XGB Classifier</b>
# </div>

# %%
import xgboost as Xgb
xgb = Xgb.XGBClassifier()
xgb.fit(X_train,y_train)
y_pred_xgb = xgb.predict(X_test)
xgb.score(X_train, y_train)

xgb_train = round(xgb.score(X_train, y_train) * 100, 2)
xgb_accuracy = round(accuracy_score(y_pred_xgb, y_test) * 100, 2)

print("Training Accuracy    :",xgb_train ,"%")
print("Model Accuracy Score :",xgb_accuracy ,"%")
print("\033[1m--------------------------------------------------------\033[0m")
print("Classification_Report: \n",classification_report(y_test,y_pred_xgb))
print("\033[1m--------------------------------------------------------\033[0m")
# Out:
# Training Accuracy    : 100.0 %
# Model Accuracy Score : 100.0 %
# --------------------------------------------------------
# Classification_Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        27
#            1       1.00      1.00      1.00        17
#            2       1.00      1.00      1.00        35
#            3       1.00      1.00      1.00        14
#            4       1.00      1.00      1.00        20
#            5       1.00      1.00      1.00        33
#            6       1.00      1.00      1.00        15
#            7       1.00      1.00      1.00        17
#            8       1.00      1.00      1.00        25
#            9       1.00      1.00      1.00        26
#           10       1.00      1.00      1.00        20
#           11       1.00      1.00      1.00        21
#           12       1.00      1.00      1.00        20
#           13       1.00      1.00      1.00        28
#           14       1.00      1.00      1.00        54
#
#     accuracy                           1.00       372
#    macro avg       1.00      1.00      1.00       372
# weighted avg       1.00      1.00      1.00       372
#
# --------------------------------------------------------

# %% [markdown]
# <div style="display:fill;
#             border-radius:15px;
#             background-color:cyan;
#             font-size:210%;
#             font-family:Vardana;
#             letter-spacing:0.5px;
#             padding:10px;
#             color:Brown;
#             border-style: solid;
#             border-color: red;
#             text-align:Left;">
# <b>Support Vector Machines</b>
# </div>

# %%
# Support Vector Machines
from sklearn.svm import SVC
svc = SVC()
svc.fit(X_train, y_train)
y_pred_svc = svc.predict(X_test)

svc_train = round(svc.score(X_train, y_train) * 100, 2)
svc_accuracy = round(accuracy_score(y_pred_svc, y_test) * 100, 2)

print("Training Accuracy    :",svc_train ,"%")
print("Model Accuracy Score :",svc_accuracy ,"%")
print("\033[1m--------------------------------------------------------\033[0m")
print("Classification_Report: \n",classification_report(y_test,y_pred_svc))
print("\033[1m--------------------------------------------------------\033[0m")
# Out:
# Training Accuracy    : 38.94 %
# Model Accuracy Score : 36.02 %
# --------------------------------------------------------
# Classification_Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        27
#            1       0.17      0.12      0.14        17
#            2       0.50      0.54      0.52        35
#            3       0.29      0.14      0.19        14
#            4       0.35      0.35      0.35        20
#            5       0.00      0.00      0.00        33
#            6       1.00      0.13      0.24        15
#            7       0.28      0.29      0.29        17
#            8       0.00      0.00      0.00        25
#            9       0.57      0.46      0.51        26
#           10       0.63      0.60      0.62        20
#           11       0.50      0.10      0.16        21
#           12       0.00      0.00      0.00        20
#           13       0.57      0.61      0.59        28
#           14       0.27      1.00      0.42        54
#
#     accuracy                           0.36       372
#    macro avg       0.34      0.29      0.27       372
# weighted avg       0.32      0.36      0.29       372
#
# --------------------------------------------------------

# %% [markdown]
# <h1 style="background-color:black
# ;font-family:newtimeroman;font-size:350%;text-align:center;border-radius: 150px 150px; color:#40E0D0"> Comparing Different Models </h1><a id=0></a>

# %%
models = pd.DataFrame({
    'Model': [
        'Support Vector Machines', 'Logistic Regression', 'Random Forest',
        'Decision Tree', 'XGBClassifier'
    ],

    'Training Accuracy':
    [log_train, svc_train, decision_train, random_forest_train, xgb_train],

    'Model Accuracy Score': [
        log_accuracy, svc_accuracy, decision_accuracy, random_forest_accuracy,
        xgb_accuracy
    ]
})

# %% [markdown]
# <h1 style="background-color:black
# ;font-family:newtimeroman;font-size:350%;text-align:center;border-radius: 150px 150px; color:#40E0D0"> Result Prediction</h1><a id=0></a>

# %% [markdown]
# <span style="background-color:yellow;
#              color:Black;
#              font-size:25px;
#              text-align:center;
#              border-radius:30px 80px;
#              font-weight:bold;
#              border:2px solid red;
#              padding:0px 20px;">1. Random Forest Classifier
# </span>

# %%
prediction1 = random_forest.predict(X_test)
print(prediction1)
# Out:
# [ 1 13  1  9 10 11  6 14  0  4  0  1  8  1  5 12  5 12 13 10  8  5  9  3
#   8  2  8 14 11  8  4 13  1 14 13  9 14 10 14 10 13  4 14  9 10  0 14  9
#  10  2  9  7  4  7 13  4  9  8  0 10 12 14 11 11 14  2  4 14  0 14 12  9
#  14  8 11 10  7  0  2  8 12  7 11  5 10  1 14  1  2  9 14  7  8  7  8 13
#   3 14  9  9  2  3  7  1  1  5  4  5 14  0 14  2 13  0 14 14 13  3 14  2
#   8  9  5  8  7  2  5  2  7 11  6 12  9 12  9  9  2 10  5  2 13  3  0 12
#  14 14 12 11  1  6  2 14 13  0 14 11  5  5  6  9 12  0  8  2  0  0 12  3
#  12  5 12  7 11 14 14 11 13 13  0  8 14  5 12  2  7 14  3  1  8  0  5  1
#   6  2  2 14  7  4  6 13 13  9 13  1  4  1  2  7  6 12 14 11  0 13 14 13
#   5  9  9  2 14 11 13  5  4  3 14  0  4 14  8 14 11  4 10  3 14  3 11 13
#   6 13  3  2 14 10 14  4 14  6  8  0 13 10  5 14  5  0  6  0 10  8  2  4
#   1 11  6  7 13  3  8  2  2 11  9  5 12 13  4  0  9  4  5  7 10  8  1 14
#  11 14 11 12  2  9  4  8  5  5  4  7  6  0  6  0 14  5  7  6  2 10 11  5
#   2  9 14  2 14 11 12  3  4  5  8  5 14 14 13  5  3 13  8  5  6 14  2 12
#   5  4  9  0  0 10  2 14 14 12 10  2  5 14  8 14  5  0  0  1  2  5 14  5
#   2  2  2  2  9 10 13 14  9 13  8 10]

# %%
cross_checking = pd.DataFrame({'Actual' : y_test , 'Predicted' : prediction1})
cross_checking.sample(5).style.background_gradient(
        cmap='coolwarm').set_properties(**{
            'color': 'LigntGreen',
            'font-size': '15px'
        })
# Out:
# <style type="text/css">
# #T_fff58_row0_col0, #T_fff58_row0_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_fff58_row1_col0, #T_fff58_row1_col1 {
#   background-color: #f7b89c;
#   color: #000000;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_fff58_row2_col0, #T_fff58_row2_col1 {
#   background-color: #d95847;
#   color: #f1f1f1;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_fff58_row3_col0, #T_fff58_row3_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_fff58_row4_col0, #T_fff58_row4_col1 {
#   background-color: #ead4c8;
#   color: #000000;
#   color: LigntGreen;
#   font-size: 15px;
# }
# </style>
# <table id="T_fff58" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fff58_level0_col0" class="col_heading level0 col0" >Actual</th>
#       <th id="T_fff58_level0_col1" class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fff58_level0_row0" class="row_heading level0 row0" >1211</th>
#       <td id="T_fff58_row0_col0" class="data row0 col0" >11</td>
#       <td id="T_fff58_row0_col1" class="data row0 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_fff58_level0_row1" class="row_heading level0 row1" >810</th>
#       <td id="T_fff58_row1_col0" class="data row1 col0" >8</td>
#       <td id="T_fff58_row1_col1" class="data row1 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_fff58_level0_row2" class="row_heading level0 row2" >371</th>
#       <td id="T_fff58_row2_col0" class="data row2 col0" >10</td>
#       <td id="T_fff58_row2_col1" class="data row2 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_fff58_level0_row3" class="row_heading level0 row3" >1747</th>
#       <td id="T_fff58_row3_col0" class="data row3 col0" >2</td>
#       <td id="T_fff58_row3_col1" class="data row3 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_fff58_level0_row4" class="row_heading level0 row4" >1159</th>
#       <td id="T_fff58_row4_col0" class="data row4 col0" >7</td>
#       <td id="T_fff58_row4_col1" class="data row4 col1" >7</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <span style="background-color:yellow;
#              color:Black;
#              font-size:25px;
#              text-align:center;
#              border-radius:30px 80px;
#              font-weight:bold;
#              border:2px solid red;
#              padding:0px 20px;">2. Decision Tree Classifier
# </span>

# %%
prediction2 = decision.predict(X_test)
print(prediction2)
# Out:
# [ 1 13  1  9 10 11  6 14  0  4  0  1  8  1  5 12  5 12 13 10  8  5  9  3
#   8  2  8 14 11  8  4 13  1 14 13  9 14 10 14 10 13  4 14  9 10  0 14  9
#  10  2  9  7  4  7 13  4  9  8  0 10 12 14 11 11 14  2  4 14  0 14 12  9
#  14  8 11 10  7  0  2  8 12  7 11  5 10  1 14  1  2  9 14  7  8  7  8 13
#   3 14  9  9  2  3  7  1  1  5  4  5 14  0 14  2 13  0 14 14 13  3 14  2
#   8  9  5  8  7  2  5  2  7 11  6 12  9 12  9  9  2 10  5  2 13  3  0 12
#  14 14 12 11  1  6  2 14 13  0 14 11  5  5  6  9 12  0  8  2  0  0 12  3
#  12  5 12  7 11 14 14 11 13 13  0  8 14  5 12  2  7 14  3  1  8  0  5  1
#   6  2  2 14  7  4  6 13 13  9 13  1  4  1  2  7  6 12 14 11  0 13 14 13
#   5  9  9  2 14 11 13  5  4  3 14  0  4 14  8 14 11  4 10  3 14  3 11 13
#   6 13  3  2 14 10 14  4 14  6  8  0 13 10  5 14  5  0  6  0 10  8  2  4
#   1 11  6  7 13  3  8  2  2 11  9  5 12 13  4  0  9  4  5  7 10  8  1 14
#  11 14 11 12  2  9  4  8  5  5  4  7  6  0  6  0 14  5  7  6  2 10 11  5
#   2  9 14  2 14 11 12  3  4  5  8  5 14 14 13  5  3 13  8  5  6 14  2 12
#   5  4  9  0  0 10  2 14 14 12 10  2  5 14  8 14  5  0  0  1  2  5 14  5
#   2  2  2  2  9 10 13 14  9 13  8 10]

# %%
cross_checking = pd.DataFrame({'Actual' : y_test , 'Predicted' : prediction2})
cross_checking.sample(5).style.background_gradient(
        cmap='coolwarm').set_properties(**{
            'color': 'LigntGreen',
            'font-size': '15px'
        })
# Out:
# <style type="text/css">
# #T_8b8b4_row0_col0, #T_8b8b4_row0_col1 {
#   background-color: #6788ee;
#   color: #f1f1f1;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_8b8b4_row1_col0, #T_8b8b4_row1_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_8b8b4_row2_col0, #T_8b8b4_row2_col1, #T_8b8b4_row4_col0, #T_8b8b4_row4_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_8b8b4_row3_col0, #T_8b8b4_row3_col1 {
#   background-color: #f6bfa6;
#   color: #000000;
#   color: LigntGreen;
#   font-size: 15px;
# }
# </style>
# <table id="T_8b8b4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8b8b4_level0_col0" class="col_heading level0 col0" >Actual</th>
#       <th id="T_8b8b4_level0_col1" class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8b8b4_level0_row0" class="row_heading level0 row0" >1786</th>
#       <td id="T_8b8b4_row0_col0" class="data row0 col0" >2</td>
#       <td id="T_8b8b4_row0_col1" class="data row0 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_8b8b4_level0_row1" class="row_heading level0 row1" >42</th>
#       <td id="T_8b8b4_row1_col0" class="data row1 col0" >14</td>
#       <td id="T_8b8b4_row1_col1" class="data row1 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_8b8b4_level0_row2" class="row_heading level0 row2" >710</th>
#       <td id="T_8b8b4_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_8b8b4_row2_col1" class="data row2 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_8b8b4_level0_row3" class="row_heading level0 row3" >1562</th>
#       <td id="T_8b8b4_row3_col0" class="data row3 col0" >9</td>
#       <td id="T_8b8b4_row3_col1" class="data row3 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_8b8b4_level0_row4" class="row_heading level0 row4" >714</th>
#       <td id="T_8b8b4_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_8b8b4_row4_col1" class="data row4 col1" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <span style="background-color:yellow;
#              color:Black;
#              font-size:25px;
#              text-align:center;
#              border-radius:30px 80px;
#              font-weight:bold;
#              border:2px solid red;
#              padding:0px 20px;">3. XGB Classifier
# </span>

# %%
prediction3 = xgb.predict(X_test)
print(prediction3)
# Out:
# [ 1 13  1  9 10 11  6 14  0  4  0  1  8  1  5 12  5 12 13 10  8  5  9  3
#   8  2  8 14 11  8  4 13  1 14 13  9 14 10 14 10 13  4 14  9 10  0 14  9
#  10  2  9  7  4  7 13  4  9  8  0 10 12 14 11 11 14  2  4 14  0 14 12  9
#  14  8 11 10  7  0  2  8 12  7 11  5 10  1 14  1  2  9 14  7  8  7  8 13
#   3 14  9  9  2  3  7  1  1  5  4  5 14  0 14  2 13  0 14 14 13  3 14  2
#   8  9  5  8  7  2  5  2  7 11  6 12  9 12  9  9  2 10  5  2 13  3  0 12
#  14 14 12 11  1  6  2 14 13  0 14 11  5  5  6  9 12  0  8  2  0  0 12  3
#  12  5 12  7 11 14 14 11 13 13  0  8 14  5 12  2  7 14  3  1  8  0  5  1
#   6  2  2 14  7  4  6 13 13  9 13  1  4  1  2  7  6 12 14 11  0 13 14 13
#   5  9  9  2 14 11 13  5  4  3 14  0  4 14  8 14 11  4 10  3 14  3 11 13
#   6 13  3  2 14 10 14  4 14  6  8  0 13 10  5 14  5  0  6  0 10  8  2  4
#   1 11  6  7 13  3  8  2  2 11  9  5 12 13  4  0  9  4  5  7 10  8  1 14
#  11 14 11 12  2  9  4  8  5  5  4  7  6  0  6  0 14  5  7  6  2 10 11  5
#   2  9 14  2 14 11 12  3  4  5  8  5 14 14 13  5  3 13  8  5  6 14  2 12
#   5  4  9  0  0 10  2 14 14 12 10  2  5 14  8 14  5  0  0  1  2  5 14  5
#   2  2  2  2  9 10 13 14  9 13  8 10]

# %%
cross_checking = pd.DataFrame({'Actual' : y_test , 'Predicted' : prediction3})
cross_checking.sample(5).style.background_gradient(
        cmap='coolwarm').set_properties(**{
            'color': 'LigntGreen',
            'font-size': '15px'
        })
# Out:
# <style type="text/css">
# #T_07f33_row0_col0, #T_07f33_row0_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_07f33_row1_col0, #T_07f33_row1_col1 {
#   background-color: #f2cbb7;
#   color: #000000;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_07f33_row2_col0, #T_07f33_row2_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_07f33_row3_col0, #T_07f33_row3_col1 {
#   background-color: #f7ac8e;
#   color: #000000;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_07f33_row4_col0, #T_07f33_row4_col1 {
#   background-color: #9ebeff;
#   color: #000000;
#   color: LigntGreen;
#   font-size: 15px;
# }
# </style>
# <table id="T_07f33" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_07f33_level0_col0" class="col_heading level0 col0" >Actual</th>
#       <th id="T_07f33_level0_col1" class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_07f33_level0_row0" class="row_heading level0 row0" >1814</th>
#       <td id="T_07f33_row0_col0" class="data row0 col0" >2</td>
#       <td id="T_07f33_row0_col1" class="data row0 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_07f33_level0_row1" class="row_heading level0 row1" >848</th>
#       <td id="T_07f33_row1_col0" class="data row1 col0" >8</td>
#       <td id="T_07f33_row1_col1" class="data row1 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_07f33_level0_row2" class="row_heading level0 row2" >875</th>
#       <td id="T_07f33_row2_col0" class="data row2 col0" >12</td>
#       <td id="T_07f33_row2_col1" class="data row2 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_07f33_level0_row3" class="row_heading level0 row3" >1574</th>
#       <td id="T_07f33_row3_col0" class="data row3 col0" >9</td>
#       <td id="T_07f33_row3_col1" class="data row3 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_07f33_level0_row4" class="row_heading level0 row4" >316</th>
#       <td id="T_07f33_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_07f33_row4_col1" class="data row4 col1" >5</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <span style="background-color:yellow;
#              color:Black;
#              font-size:25px;
#              text-align:center;
#              border-radius:30px 80px;
#              font-weight:bold;
#              border:2px solid red;
#              padding:0px 20px;">4. Support Vector Machines
# </span>

# %%
prediction4 = svc.predict(X_test)
print(prediction4)
# Out:
# [ 2 13  2 13 14 14 14 14 14  1 14  1 14  7 14 14 14 14 13 10 14 14  9 10
#  14  2 14 14  9 14 13 14  2 14 14 11 14 10 14 10 14  4 14 10 10 14 14  9
#  14  2  9 14  1 14 14  7 13 14 14 10 14 14  9 14 14  1 13 14 14 14 14  9
#  14 14 11 10 14 14  2 14 14  4 14  4 10  2 14  9  2 13 14  4 14 14 14 14
#   2 14 13  9  7 10 14  2  9 14  7 14 14 14 14  1 13 14 14 14 13  4 14  2
#  14 10 14 14  7  2 14  9  7 14  2 14  9 14  9  9  2 10 14  2 14  4 14 14
#  14 14 14 14  2  2  2 14 13 14 14 14 14 14 14  9 14 14 14  1 14 14 14  4
#  14 14 14 14 14 14 14 14 13 14 14 14 14 14 14  2  7 14  3  2 14 14 14  2
#   3  1  1 14  7  4 14 13 14 13 13  7  4  9  2 14  3 14 14 14 14 13 14 13
#  14  9 13  2 14  2 14  4 13 10 14 14  4 14 14 14 14 13 10  4 14  4 14 13
#   6 13 10  2 14 14 14  1 14  6 14 14 13 10 14 14 14 14  2 14 14 14  9  7
#   2 14  3  7 13  2 14  7  7  9 13 14 14 14 13 14 13  4 14 14 14 14  2 14
#   2 14 11 14  2 11  1 14  4 14  4 14  3 14 14 14 14  4 14 14  9 10 14 14
#   7  9 14  1 14 14 14  3  7  4 14 14 14 14 14 14  2 13 14  4  3 14  2 14
#  14  4 10 14 14 14  7 14 14 14 10  2 14 14 14 14 14 14 14  1  2 14 14 14
#   7  7  2  2  9 14 13 14  2 13 14 14]

# %%
cross_checking = pd.DataFrame({'Actual' : y_test , 'Predicted' : prediction4})
cross_checking.sample(5).style.background_gradient(
        cmap='coolwarm').set_properties(**{
            'color': 'LigntGreen',
            'font-size': '15px'
        })
# Out:
# <style type="text/css">
# #T_e6100_row0_col0, #T_e6100_row2_col0, #T_e6100_row2_col1, #T_e6100_row3_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_e6100_row0_col1 {
#   background-color: #cf453c;
#   color: #f1f1f1;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_e6100_row1_col0, #T_e6100_row1_col1, #T_e6100_row4_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_e6100_row3_col0 {
#   background-color: #94b6ff;
#   color: #000000;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_e6100_row4_col0 {
#   background-color: #7597f6;
#   color: #f1f1f1;
#   color: LigntGreen;
#   font-size: 15px;
# }
# </style>
# <table id="T_e6100" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e6100_level0_col0" class="col_heading level0 col0" >Actual</th>
#       <th id="T_e6100_level0_col1" class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e6100_level0_row0" class="row_heading level0 row0" >508</th>
#       <td id="T_e6100_row0_col0" class="data row0 col0" >13</td>
#       <td id="T_e6100_row0_col1" class="data row0 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_e6100_level0_row1" class="row_heading level0 row1" >1771</th>
#       <td id="T_e6100_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_e6100_row1_col1" class="data row1 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e6100_level0_row2" class="row_heading level0 row2" >599</th>
#       <td id="T_e6100_row2_col0" class="data row2 col0" >13</td>
#       <td id="T_e6100_row2_col1" class="data row2 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_e6100_level0_row3" class="row_heading level0 row3" >318</th>
#       <td id="T_e6100_row3_col0" class="data row3 col0" >5</td>
#       <td id="T_e6100_row3_col1" class="data row3 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_e6100_level0_row4" class="row_heading level0 row4" >1471</th>
#       <td id="T_e6100_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_e6100_row4_col1" class="data row4 col1" >1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <span style="background-color:yellow;
#              color:Black;
#              font-size:25px;
#              text-align:center;
#              border-radius:30px 80px;
#              font-weight:bold;
#              border:2px solid red;
#              padding:0px 20px;">5. Logistic Regression
# </span>

# %%
prediction5 = logreg.predict(X_test)
print(prediction5)
# Out:
# [ 2 13  1 13 10 11  6 14  5 13  5  1  8  7  5 13  5 13 13 10  8  5 13  5
#   8  2  8 14  9  8 13 13  1 14 13 13 14 10 14  9 13 13 14 13 10  5 14 13
#  10  2 13 13 13 13 13 13 13  8  5 10 13 14  9 11 14  2 13 14  5 14 13 13
#  14  8 11 10 13  5  2  8 13  4 11  5 10  1 14  1  2 13 14  4  8 13  8 13
#   3 14 13 13  2  5 13  1  1  5 13  5 14  5 14 13 13  5 14 14 13  5 14  2
#   8 13  5  8  7  2  5  2  7 11  6 13  9 13  9 13  2 10  5  2 13  5  5 13
#  14 14 13 11  2  6  2 14 13  5 14 11  5  5  8 13 13  5  8 13  5  5 13  5
#  13  5 13 13 11 14 14 11 13 13  5  8 14  5 13  2 13 14  5  2  8  5  5  1
#   8  2 13 14  7 13  8 13 13 13 13  7 13  1  2 13  8 13 14 11  5 13 14 13
#   5 13 13  2 14 11 13  5 13  5 14  5 13 14  8 14 11 13 10  5 14  5 11 13
#   6 13  5  2 14 10 14 13 14  6  8  5 13 10  5 14  5  5  6  5 10  8  2 13
#   1 11  6  7 13  3  8  2  2  9 13  5 13 13 13  5 13 13  5 13 10  8  1 14
#  11 14 11 13  2 13 13  8  5  5 13 13  8  5  8  5 14  5 13  8  2 10 11  5
#   2 13 14 13 14 11 13  5 13  5  8  5 14 14 13  5  3 13  8  5  6 14  2 13
#   5 13 13  5  5 10  2 14 14 13 10  2  5 14  8 14  5  5  5  2  2  5 14  5
#   2  2  2  2 13 10 13 14 13 13  8 10]

# %%
cross_checking = pd.DataFrame({'Actual' : y_test , 'Predicted' : prediction5})
cross_checking.sample(5).style.background_gradient(
        cmap='coolwarm').set_properties(**{
            'font-family': 'Lucida Calligraphy',
            'color': 'LigntGreen',
            'font-size': '15px'
        })
# Out:
# <style type="text/css">
# #T_5a3e3_row0_col0, #T_5a3e3_row0_col1, #T_5a3e3_row1_col1, #T_5a3e3_row4_col0, #T_5a3e3_row4_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_5a3e3_row1_col0 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_5a3e3_row2_col0 {
#   background-color: #8db0fe;
#   color: #000000;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_5a3e3_row2_col1, #T_5a3e3_row3_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_5a3e3_row3_col1 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# </style>
# <table id="T_5a3e3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5a3e3_level0_col0" class="col_heading level0 col0" >Actual</th>
#       <th id="T_5a3e3_level0_col1" class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5a3e3_level0_row0" class="row_heading level0 row0" >552</th>
#       <td id="T_5a3e3_row0_col0" class="data row0 col0" >13</td>
#       <td id="T_5a3e3_row0_col1" class="data row0 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_5a3e3_level0_row1" class="row_heading level0 row1" >912</th>
#       <td id="T_5a3e3_row1_col0" class="data row1 col0" >12</td>
#       <td id="T_5a3e3_row1_col1" class="data row1 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_5a3e3_level0_row2" class="row_heading level0 row2" >1063</th>
#       <td id="T_5a3e3_row2_col0" class="data row2 col0" >7</td>
#       <td id="T_5a3e3_row2_col1" class="data row2 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_5a3e3_level0_row3" class="row_heading level0 row3" >350</th>
#       <td id="T_5a3e3_row3_col0" class="data row3 col0" >5</td>
#       <td id="T_5a3e3_row3_col1" class="data row3 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_5a3e3_level0_row4" class="row_heading level0 row4" >576</th>
#       <td id="T_5a3e3_row4_col0" class="data row4 col0" >13</td>
#       <td id="T_5a3e3_row4_col1" class="data row4 col1" >13</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div style="color:white;
#        display:fill;
#        border-radius:5px;
#        background-color:yellow;
#        font-size:120%;
#        font-family:Nexa;
#        style:justify;
#        font-family:'Times New Roman';
#        letter-spacing:0.5px">
#     <p style="padding: 10px;
#           color:Black;">
#          Random Forest,Decision Tree Classifier,XGB Classifier,	are giving the best Result with 100 percent accuracy and  is doing  a great job till now in Fault Detection, than the rest of the models because it's able to predict all the signals in most efficient manner while in other models there are cases where there is actually fault but the model is not able to identify it.Logistic Regression is giving the worst accuracy
#     </p>
# </div>
