# %% [markdown]
# <a href="https://colab.research.google.com/github/marwan229/Data_Science-project/blob/main/2overcurrentipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <span style="background-color:red;
#              color:white;
#              font-size:17px;
#              text-align:center;
#              border-radius:30px 80px;
#              font-weight:bold;
#              border:2px solid red;
#              padding:0px 20px;">What are Electrical Faults?
# </span>

# %% [markdown]
# <div style="color:white;
#        display:fill;
#        border-radius:5px;
#        background-color:yellow;
#        font-size:120%;
#        font-family:Nexa;
#        style:justify;
#        font-family:'Times New Roman';
#        letter-spacing:0.5px">
#     <p style="padding: 10px;
#           color:Black;">
#          Normally, a power system operates under balanced conditions. When the system becomes unbalanced due to the failures of insulation at any point or due to the contact of live wires, a short–circuit or fault, is said to occur in the line. Faults may occur in the power system due to the number of reasons like natural disturbances (lightning, high-speed winds, earthquakes), insulation breakdown, falling of a tree, bird shorting, etc.
#     </p>
# </div>

# %% [markdown]
# <span style="background-color:red;
#              color:white;
#              font-size:17px;
#              text-align:center;
#              border-radius:30px 80px;
#              font-weight:bold;
#              border:2px solid red;
#              padding:0px 20px;">Types of Faults?
# </span>

# %% [markdown]
# <div style="color:white;
#        display:fill;
#        border-radius:5px;
#        background-color:yellow;
#        font-size:120%;
#        font-family:Nexa;
#        style:justify;
#        font-family:'Times New Roman';
#        letter-spacing:0.5px">
#     <p style="padding: 10px;
#           color:Black;">
#          Normally, a power system operates under balanced conditions. When the system becomes unbalanced due to the failures of insulation at any point or due to the contact of live wires, a short–circuit or fault, is said to occur in the line. Faults may occur in the power system due to the number of reasons like natural disturbances (lightning, high-speed winds, earthquakes), insulation breakdown, falling of a tree, bird shorting, etc.
#     </p>
# </div>

# %% [markdown]
# <span style="background-color:red;
#              color:white;
#              font-size:17px;
#              text-align:center;
#              border-radius:30px 80px;
#              font-weight:bold;
#              border:2px solid red;
#              padding:0px 20px;">Faults can be brodly categorised into two types:
# </span>

# %% [markdown]
# **1. Open-circuit Fault**
#
# **2. Short-Circuit Faults**

# %% [markdown]
# <span style="background-color:Blue;
#              color:white;
#              font-size:17px;
#              text-align:center;
#              border-radius:30px 80px;
#              font-weight:bold;
#              border:2px solid Blue;
#              padding:0px 20px;">Short-Circuit Faults
# </span>

# %% [markdown]
# **1. Symmetrical**
#
# **2. Asymmetrical Faults**

# %% [markdown]
# <span style="background-color:red;
#              color:white;
#              font-size:17px;
#              text-align:center;
#              border-radius:30px 80px;
#              font-weight:bold;
#              border:2px solid red;
#              padding:0px 20px;">Symmetrical and Asymmetrical Faults
# </span>

# %% [markdown]
# <span style="background-color:Blue;
#              color:white;
#              font-size:17px;
#              text-align:center;
#              border-radius:30px 80px;
#              font-weight:bold;
#              border:2px solid Blue;
#              padding:0px 20px;">Symmetrical Faults
# </span>

# %% [markdown]
# > * In symmetrical faults, all phases are shorted to each other or to earth (L-L-L) or (L-L-L-G).
# > * The nature of this type of fault is balanced.
# > * In this type of fault,fault currents in all phases are symmetrical i.e. their magnitudes are equal and they are equally displaced by angle 120 degree.
# > * It is more severe type of fault but it occurs rarely.

# %% [markdown]
# <span style="background-color:Blue;
#              color:white;
#              font-size:17px;
#              text-align:center;
#              border-radius:30px 80px;
#              font-weight:bold;
#              border:2px solid Blue;
#              padding:0px 20px;">Asymmetrical Faults
# </span>

# %% [markdown]
# > * These faults involve only one or two phases.
# > * In this type of fault, three phase lines become unbalanced.
# > * There are mainly three types namely line to ground (L-G), line to line (L-L) and double line to ground (LL-G) faults.
# > * These type of faults mostly occur on power system..

# %% [markdown]
# <center> <img src="https://ars.els-cdn.com/content/image/1-s2.0-S2314717217300065-gr1.jpg" width="600" height="200"> </center>

# %% [markdown]
# <span style="background-color:red;
#              color:white;
#              font-size:17px;
#              text-align:center;
#              border-radius:30px 80px;
#              font-weight:bold;
#              border:2px solid red;
#              padding:0px 20px;">About this dataset file
# </span>

# %% [markdown]
# **This file contains the dataset to classify the types of fault.**
#
# - Inputs - [Ia,Ib,Ic,Va,Vb,Vc]
#
# > Ia = Current in line A
#
# > Ib = Current in line B
#
# > Ic = Current in line C
#
#
# > Va = Voltage in line A
#
# > Vb = Voltage in line B
#
# > Vc = Voltage in line C
#
# *Examples :*
#
# - [G C B A] - Outputs
#
# - [0 0 0 0] - No Fault
#
#
# - [1 0 0 0] - Ground Fault
#
#
# - [0 0 0 1] - Fault in Line A
# - [0 0 1 0] - Fault in Line B
# - [0 1 0 0] - Fault in Line C
#
#
# - [1 0 0 1] - LG fault (Between Phase A and Ground)
# - [1 0 1 0] - LG fault (Between Phase B and Ground)
# - [1 1 0 0] - LG fault (Between Phase C and Ground)
#
#
# - [0 0 1 1] - LL fault (Between Phase B and Phase A)
# - [0 1 1 0] - LL fault (Between Phase C and Phase B)
# - [0 1 0 1] - LL fault (Between Phase C and Phase A)
#
#
# - [1 0 1 1] - LLG Fault (Between Phases A,B and Ground)
# - [1 1 0 1] - LLG Fault (Between Phases A,C and Ground)
# - [1 1 1 0] - LLG Fault (Between Phases C,B and Ground)
#
#
# - [0 1 1 1] - LLL Fault(Between all three phases)
#
#
# - [1 1 1 1] - LLLG fault( Three phase symmetrical fault)

# %% [markdown]
# <span class="label label-default" style="background-color:#DC1010; border-radius:12px; font-weight: bold; font-family:Verdana; font-size:28px; color:#FBFAFC; ">Objectives of Notebook</span>

# %% [markdown]
# <span class="label label-default" style="background-color:#DC1010; border-radius:12px; font-weight: bold; font-family:Verdana; font-size:28px; color:#FBFAFC; ">Importing Libraries:</span>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
sns.set_theme(context='notebook',
              style='white',
              palette='deep',

              font_scale=1.5,
              color_codes=True,
              rc=None)

import matplotlib

plt.rcParams['figure.figsize'] = (14,8)
plt.rcParams['figure.facecolor'] = '#F0F8FF'
plt.rcParams['figure.titlesize'] = 'medium'
plt.rcParams['figure.dpi'] = 150
plt.rcParams['figure.edgecolor'] = 'green'
plt.rcParams['figure.frameon'] = True

plt.rcParams["figure.autolayout"] = True

plt.rcParams['axes.facecolor'] = '#F5F5DC'
plt.rcParams['axes.titlesize'] = 25
plt.rcParams["axes.titleweight"] = 'normal'
plt.rcParams["axes.titlecolor"] = 'Olive'
plt.rcParams['axes.edgecolor'] = 'pink'

plt.rcParams["axes.linewidth"] = 2
plt.rcParams["axes.grid"] = True
plt.rcParams['axes.titlelocation'] = 'center'
plt.rcParams["axes.labelsize"] = 20
plt.rcParams["axes.labelpad"] = 2
plt.rcParams['axes.labelweight'] = 1
plt.rcParams["axes.labelcolor"] = 'Olive'
plt.rcParams["axes.axisbelow"] = False
plt.rcParams['axes.xmargin'] = .2
plt.rcParams["axes.ymargin"] = .2

plt.rcParams["xtick.bottom"] = True
plt.rcParams['xtick.color'] = '#A52A2A'
plt.rcParams["ytick.left"] = True
plt.rcParams['ytick.color'] = '#A52A2A'

plt.rcParams['axes.grid'] = True
plt.rcParams['grid.color'] = 'green'
plt.rcParams['grid.linestyle'] = '--'
plt.rcParams['grid.linewidth'] = .5
plt.rcParams['grid.alpha'] = .3

plt.rcParams['legend.loc'] = 'best'
plt.rcParams['legend.facecolor'] =  'NavajoWhite'
plt.rcParams['legend.edgecolor'] = 'pink'
plt.rcParams['legend.shadow'] = True
plt.rcParams['legend.fontsize'] = 20



plt.rcParams['font.size'] = 14

plt.rcParams['figure.dpi'] = 150
plt.rcParams['figure.edgecolor'] = 'Blue'

# %%
df_class = pd.read_csv("/content/class.csv")
df_class.sample(5).style.set_properties(**{'background-color': 'blue',
                           'color': 'white',
                           'border-color': 'darkblack'})
# Out:
# <style type="text/css">
# #T_e77c3_row0_col0, #T_e77c3_row0_col1, #T_e77c3_row0_col2, #T_e77c3_row0_col3, #T_e77c3_row0_col4, #T_e77c3_row0_col5, #T_e77c3_row0_col6, #T_e77c3_row1_col0, #T_e77c3_row1_col1, #T_e77c3_row1_col2, #T_e77c3_row1_col3, #T_e77c3_row1_col4, #T_e77c3_row1_col5, #T_e77c3_row1_col6, #T_e77c3_row2_col0, #T_e77c3_row2_col1, #T_e77c3_row2_col2, #T_e77c3_row2_col3, #T_e77c3_row2_col4, #T_e77c3_row2_col5, #T_e77c3_row2_col6, #T_e77c3_row3_col0, #T_e77c3_row3_col1, #T_e77c3_row3_col2, #T_e77c3_row3_col3, #T_e77c3_row3_col4, #T_e77c3_row3_col5, #T_e77c3_row3_col6, #T_e77c3_row4_col0, #T_e77c3_row4_col1, #T_e77c3_row4_col2, #T_e77c3_row4_col3, #T_e77c3_row4_col4, #T_e77c3_row4_col5, #T_e77c3_row4_col6 {
#   background-color: blue;
#   color: white;
#   border-color: darkblack;
# }
# </style>
# <table id="T_e77c3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e77c3_level0_col0" class="col_heading level0 col0" >Ia</th>
#       <th id="T_e77c3_level0_col1" class="col_heading level0 col1" >Ib</th>
#       <th id="T_e77c3_level0_col2" class="col_heading level0 col2" >Ic</th>
#       <th id="T_e77c3_level0_col3" class="col_heading level0 col3" >G</th>
#       <th id="T_e77c3_level0_col4" class="col_heading level0 col4" >C</th>
#       <th id="T_e77c3_level0_col5" class="col_heading level0 col5" >B</th>
#       <th id="T_e77c3_level0_col6" class="col_heading level0 col6" >A</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e77c3_level0_row0" class="row_heading level0 row0" >728</th>
#       <td id="T_e77c3_row0_col0" class="data row0 col0" >53.872519</td>
#       <td id="T_e77c3_row0_col1" class="data row0 col1" >-538.872519</td>
#       <td id="T_e77c3_row0_col2" class="data row0 col2" >-0.000000</td>
#       <td id="T_e77c3_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_e77c3_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_e77c3_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_e77c3_row0_col6" class="data row0 col6" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e77c3_level0_row1" class="row_heading level0 row1" >1788</th>
#       <td id="T_e77c3_row1_col0" class="data row1 col0" >-18026.027170</td>
#       <td id="T_e77c3_row1_col1" class="data row1 col1" >-11413.251890</td>
#       <td id="T_e77c3_row1_col2" class="data row1 col2" >29439.279070</td>
#       <td id="T_e77c3_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_e77c3_row1_col4" class="data row1 col4" >1</td>
#       <td id="T_e77c3_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_e77c3_row1_col6" class="data row1 col6" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e77c3_level0_row2" class="row_heading level0 row2" >7479</th>
#       <td id="T_e77c3_row2_col0" class="data row2 col0" >55.236315</td>
#       <td id="T_e77c3_row2_col1" class="data row2 col1" >-3.679429</td>
#       <td id="T_e77c3_row2_col2" class="data row2 col2" >-52.902664</td>
#       <td id="T_e77c3_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_e77c3_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_e77c3_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_e77c3_row2_col6" class="data row2 col6" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e77c3_level0_row3" class="row_heading level0 row3" >7996</th>
#       <td id="T_e77c3_row3_col0" class="data row3 col0" >-14.897037</td>
#       <td id="T_e77c3_row3_col1" class="data row3 col1" >93.179570</td>
#       <td id="T_e77c3_row3_col2" class="data row3 col2" >-81.666461</td>
#       <td id="T_e77c3_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_e77c3_row3_col4" class="data row3 col4" >0</td>
#       <td id="T_e77c3_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_e77c3_row3_col6" class="data row3 col6" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e77c3_level0_row4" class="row_heading level0 row4" >4531</th>
#       <td id="T_e77c3_row4_col0" class="data row4 col0" >47.261062</td>
#       <td id="T_e77c3_row4_col1" class="data row4 col1" >22.980774</td>
#       <td id="T_e77c3_row4_col2" class="data row4 col2" >-67.533619</td>
#       <td id="T_e77c3_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_e77c3_row4_col4" class="data row4 col4" >1</td>
#       <td id="T_e77c3_row4_col5" class="data row4 col5" >1</td>
#       <td id="T_e77c3_row4_col6" class="data row4 col6" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <span style="background-color:red;
#              color:white;
#              font-size:17px;
#              text-align:center;
#              border-radius:30px 80px;
#              font-weight:bold;
#              border:2px solid red;
#              padding:0px 20px;">Voltage is in Per Unit value (pu)
# </span>

# %%
df_class.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9720 entries, 0 to 9719
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Ia      9720 non-null   float64
#  1   Ib      9720 non-null   float64
#  2   Ic      9720 non-null   float64
#  3   G       9720 non-null   int64
#  4   C       9720 non-null   int64
#  5   B       9720 non-null   int64
#  6   A       9720 non-null   int64
# dtypes: float64(3), int64(4)
# memory usage: 531.7 KB

# %%
df_class.isnull().sum().sum()
# Out:
# 0

# %%
df_class.shape
# Out:
# (9720, 7)

# %%
ax = plt.subplot(1,2,1)
ax = sns.countplot(x='G', data=df_class)
ax.bar_label(ax.containers[0])
plt.title("Ground Fault", fontsize=20,color = 'Brown',pad=20)

ax =plt.subplot(1,2,2)
ax=df_class['G'].value_counts().plot.pie(explode=[0.1, 0.1],autopct='%1.2f%%',shadow=True);
ax.set_title(label = "Ground Fault", fontsize = 20,color='Brown',pad=20);

# %%
ax = plt.subplot(1,2,1)
ax = sns.countplot(x='A', data=df_class)
ax.bar_label(ax.containers[0])
plt.title("Line A Fault", fontsize=20,color = 'Brown',pad=20)

ax =plt.subplot(1,2,2)
ax=df_class['A'].value_counts().plot.pie(explode=[0.1, 0.1],autopct='%1.2f%%',shadow=True);
ax.set_title(label = "Line A Fault", fontsize = 20,color='Brown',pad=20);

# %%
ax = plt.subplot(1,2,1)
ax = sns.countplot(x='B', data=df_class)
ax.bar_label(ax.containers[0])
plt.title("Line B Fault", fontsize=20,color = 'Brown',pad=20)

ax =plt.subplot(1,2,2)
ax=df_class['B'].value_counts().plot.pie(explode=[0.1, 0.1],autopct='%1.2f%%',shadow=True);
ax.set_title(label = "Line B Fault", fontsize = 20,color='Brown',pad=20);

# %%
ax = plt.subplot(1,2,1)
ax = sns.countplot(x='C', data=df_class)
ax.bar_label(ax.containers[0])
plt.title("Line C Fault", fontsize=20,color = 'Brown',pad=20)

ax =plt.subplot(1,2,2)
ax=df_class['C'].value_counts().plot.pie(explode=[0.1, 0.1],autopct='%1.2f%%',shadow=True);
ax.set_title(label = "Line C Fault", fontsize = 20,color='Brown',pad=20);

# %% [markdown]
# <span style="background-color:red;
#              color:white;
#              font-size:17px;
#              text-align:center;
#              border-radius:30px 80px;
#              font-weight:bold;
#              border:2px solid red;
#              padding:0px 20px;">Combing all fault together in one Fault_Type
# </span>

# %%
df_class['Fault_Type'] = df_class['G'].astype('str') + df_class['C'].astype('str') + df_class['B'].astype('str') + df_class['A'].astype('str')
df_class.head().style.set_properties(**{'background-color': 'blue',
                           'color': 'white',
                           'border-color': 'darkblack'})
# Out:
# <style type="text/css">
# #T_f2dbc_row0_col0, #T_f2dbc_row0_col1, #T_f2dbc_row0_col2, #T_f2dbc_row0_col3, #T_f2dbc_row0_col4, #T_f2dbc_row0_col5, #T_f2dbc_row0_col6, #T_f2dbc_row0_col7, #T_f2dbc_row1_col0, #T_f2dbc_row1_col1, #T_f2dbc_row1_col2, #T_f2dbc_row1_col3, #T_f2dbc_row1_col4, #T_f2dbc_row1_col5, #T_f2dbc_row1_col6, #T_f2dbc_row1_col7, #T_f2dbc_row2_col0, #T_f2dbc_row2_col1, #T_f2dbc_row2_col2, #T_f2dbc_row2_col3, #T_f2dbc_row2_col4, #T_f2dbc_row2_col5, #T_f2dbc_row2_col6, #T_f2dbc_row2_col7, #T_f2dbc_row3_col0, #T_f2dbc_row3_col1, #T_f2dbc_row3_col2, #T_f2dbc_row3_col3, #T_f2dbc_row3_col4, #T_f2dbc_row3_col5, #T_f2dbc_row3_col6, #T_f2dbc_row3_col7, #T_f2dbc_row4_col0, #T_f2dbc_row4_col1, #T_f2dbc_row4_col2, #T_f2dbc_row4_col3, #T_f2dbc_row4_col4, #T_f2dbc_row4_col5, #T_f2dbc_row4_col6, #T_f2dbc_row4_col7 {
#   background-color: blue;
#   color: white;
#   border-color: darkblack;
# }
# </style>
# <table id="T_f2dbc" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f2dbc_level0_col0" class="col_heading level0 col0" >Ia</th>
#       <th id="T_f2dbc_level0_col1" class="col_heading level0 col1" >Ib</th>
#       <th id="T_f2dbc_level0_col2" class="col_heading level0 col2" >Ic</th>
#       <th id="T_f2dbc_level0_col3" class="col_heading level0 col3" >G</th>
#       <th id="T_f2dbc_level0_col4" class="col_heading level0 col4" >C</th>
#       <th id="T_f2dbc_level0_col5" class="col_heading level0 col5" >B</th>
#       <th id="T_f2dbc_level0_col6" class="col_heading level0 col6" >A</th>
#       <th id="T_f2dbc_level0_col7" class="col_heading level0 col7" >Fault_Type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f2dbc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f2dbc_row0_col0" class="data row0 col0" >0.096536</td>
#       <td id="T_f2dbc_row0_col1" class="data row0 col1" >-3.626482</td>
#       <td id="T_f2dbc_row0_col2" class="data row0 col2" >3.529946</td>
#       <td id="T_f2dbc_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_f2dbc_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_f2dbc_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_f2dbc_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_f2dbc_row0_col7" class="data row0 col7" >0000</td>
#     </tr>
#     <tr>
#       <th id="T_f2dbc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f2dbc_row1_col0" class="data row1 col0" >0.244247</td>
#       <td id="T_f2dbc_row1_col1" class="data row1 col1" >-5.771591</td>
#       <td id="T_f2dbc_row1_col2" class="data row1 col2" >5.527344</td>
#       <td id="T_f2dbc_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_f2dbc_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_f2dbc_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_f2dbc_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_f2dbc_row1_col7" class="data row1 col7" >0000</td>
#     </tr>
#     <tr>
#       <th id="T_f2dbc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f2dbc_row2_col0" class="data row2 col0" >0.457486</td>
#       <td id="T_f2dbc_row2_col1" class="data row2 col1" >-7.902264</td>
#       <td id="T_f2dbc_row2_col2" class="data row2 col2" >7.444778</td>
#       <td id="T_f2dbc_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_f2dbc_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_f2dbc_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_f2dbc_row2_col6" class="data row2 col6" >0</td>
#       <td id="T_f2dbc_row2_col7" class="data row2 col7" >0000</td>
#     </tr>
#     <tr>
#       <th id="T_f2dbc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f2dbc_row3_col0" class="data row3 col0" >0.734731</td>
#       <td id="T_f2dbc_row3_col1" class="data row3 col1" >-10.017085</td>
#       <td id="T_f2dbc_row3_col2" class="data row3 col2" >9.282354</td>
#       <td id="T_f2dbc_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_f2dbc_row3_col4" class="data row3 col4" >0</td>
#       <td id="T_f2dbc_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_f2dbc_row3_col6" class="data row3 col6" >0</td>
#       <td id="T_f2dbc_row3_col7" class="data row3 col7" >0000</td>
#     </tr>
#     <tr>
#       <th id="T_f2dbc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f2dbc_row4_col0" class="data row4 col0" >1.074442</td>
#       <td id="T_f2dbc_row4_col1" class="data row4 col1" >-12.114648</td>
#       <td id="T_f2dbc_row4_col2" class="data row4 col2" >11.040206</td>
#       <td id="T_f2dbc_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_f2dbc_row4_col4" class="data row4 col4" >0</td>
#       <td id="T_f2dbc_row4_col5" class="data row4 col5" >0</td>
#       <td id="T_f2dbc_row4_col6" class="data row4 col6" >0</td>
#       <td id="T_f2dbc_row4_col7" class="data row4 col7" >0000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <span style="background-color:red;
#              color:white;
#              font-size:17px;
#              text-align:center;
#              border-radius:30px 80px;
#              font-weight:bold;
#              border:2px solid red;
#              padding:0px 20px;">Giving the proper name to the fault according to the data description provided above
# </span>

# %%
df_class['Fault_Type'][df_class['Fault_Type'] == '0000' ] = 'NO Fault'
df_class['Fault_Type'][df_class['Fault_Type'] == '0001' ] = 'Line A Fault'
df_class['Fault_Type'][df_class['Fault_Type'] == '0010' ] = 'Line B Fault'
df_class['Fault_Type'][df_class['Fault_Type'] == '0100' ] = 'Line C Fault'
df_class['Fault_Type'][df_class['Fault_Type'] == '1001' ] = 'Line A to Ground Fault'
df_class['Fault_Type'][df_class['Fault_Type'] == '1010' ] = 'Line B to Ground Fault'
df_class['Fault_Type'][df_class['Fault_Type'] == '1100' ] = 'Line C to Ground Fault'
df_class['Fault_Type'][df_class['Fault_Type'] == '1011' ] = 'Line A Line B to Ground Fault'
df_class['Fault_Type'][df_class['Fault_Type'] == '1101' ] = 'Line A Line C to Ground Fault'
df_class['Fault_Type'][df_class['Fault_Type'] == '1110' ] = 'Line B Line C to Ground Fault'
df_class['Fault_Type'][df_class['Fault_Type'] == '0011' ] = 'Line A to Line B fault'
df_class['Fault_Type'][df_class['Fault_Type'] == '0101' ] = 'Line A to Line C Fault'
df_class['Fault_Type'][df_class['Fault_Type'] == '0110' ] = 'Line B to Line C Fault'
df_class['Fault_Type'][df_class['Fault_Type'] == '0111' ] = 'Line A Line B Line C'
df_class['Fault_Type'][df_class['Fault_Type'] == '1111' ] = 'Line A Line B Line C to Ground Fault'

# %%
df_class.sample(10).style.set_properties(**{'background-color': 'blue',
                           'color': 'white',
                           'border-color': 'darkblack'})
# Out:
# <style type="text/css">
# #T_8fee2_row0_col0, #T_8fee2_row0_col1, #T_8fee2_row0_col2, #T_8fee2_row0_col3, #T_8fee2_row0_col4, #T_8fee2_row0_col5, #T_8fee2_row0_col6, #T_8fee2_row0_col7, #T_8fee2_row1_col0, #T_8fee2_row1_col1, #T_8fee2_row1_col2, #T_8fee2_row1_col3, #T_8fee2_row1_col4, #T_8fee2_row1_col5, #T_8fee2_row1_col6, #T_8fee2_row1_col7, #T_8fee2_row2_col0, #T_8fee2_row2_col1, #T_8fee2_row2_col2, #T_8fee2_row2_col3, #T_8fee2_row2_col4, #T_8fee2_row2_col5, #T_8fee2_row2_col6, #T_8fee2_row2_col7, #T_8fee2_row3_col0, #T_8fee2_row3_col1, #T_8fee2_row3_col2, #T_8fee2_row3_col3, #T_8fee2_row3_col4, #T_8fee2_row3_col5, #T_8fee2_row3_col6, #T_8fee2_row3_col7, #T_8fee2_row4_col0, #T_8fee2_row4_col1, #T_8fee2_row4_col2, #T_8fee2_row4_col3, #T_8fee2_row4_col4, #T_8fee2_row4_col5, #T_8fee2_row4_col6, #T_8fee2_row4_col7, #T_8fee2_row5_col0, #T_8fee2_row5_col1, #T_8fee2_row5_col2, #T_8fee2_row5_col3, #T_8fee2_row5_col4, #T_8fee2_row5_col5, #T_8fee2_row5_col6, #T_8fee2_row5_col7, #T_8fee2_row6_col0, #T_8fee2_row6_col1, #T_8fee2_row6_col2, #T_8fee2_row6_col3, #T_8fee2_row6_col4, #T_8fee2_row6_col5, #T_8fee2_row6_col6, #T_8fee2_row6_col7, #T_8fee2_row7_col0, #T_8fee2_row7_col1, #T_8fee2_row7_col2, #T_8fee2_row7_col3, #T_8fee2_row7_col4, #T_8fee2_row7_col5, #T_8fee2_row7_col6, #T_8fee2_row7_col7, #T_8fee2_row8_col0, #T_8fee2_row8_col1, #T_8fee2_row8_col2, #T_8fee2_row8_col3, #T_8fee2_row8_col4, #T_8fee2_row8_col5, #T_8fee2_row8_col6, #T_8fee2_row8_col7, #T_8fee2_row9_col0, #T_8fee2_row9_col1, #T_8fee2_row9_col2, #T_8fee2_row9_col3, #T_8fee2_row9_col4, #T_8fee2_row9_col5, #T_8fee2_row9_col6, #T_8fee2_row9_col7 {
#   background-color: blue;
#   color: white;
#   border-color: darkblack;
# }
# </style>
# <table id="T_8fee2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8fee2_level0_col0" class="col_heading level0 col0" >Ia</th>
#       <th id="T_8fee2_level0_col1" class="col_heading level0 col1" >Ib</th>
#       <th id="T_8fee2_level0_col2" class="col_heading level0 col2" >Ic</th>
#       <th id="T_8fee2_level0_col3" class="col_heading level0 col3" >G</th>
#       <th id="T_8fee2_level0_col4" class="col_heading level0 col4" >C</th>
#       <th id="T_8fee2_level0_col5" class="col_heading level0 col5" >B</th>
#       <th id="T_8fee2_level0_col6" class="col_heading level0 col6" >A</th>
#       <th id="T_8fee2_level0_col7" class="col_heading level0 col7" >Fault_Type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8fee2_level0_row0" class="row_heading level0 row0" >4508</th>
#       <td id="T_8fee2_row0_col0" class="data row0 col0" >32.026161</td>
#       <td id="T_8fee2_row0_col1" class="data row0 col1" >297.668883</td>
#       <td id="T_8fee2_row0_col2" class="data row0 col2" >-326.978434</td>
#       <td id="T_8fee2_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_8fee2_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_8fee2_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_8fee2_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_8fee2_row0_col7" class="data row0 col7" >Line B to Line C Fault</td>
#     </tr>
#     <tr>
#       <th id="T_8fee2_level0_row1" class="row_heading level0 row1" >8327</th>
#       <td id="T_8fee2_row1_col0" class="data row1 col0" >44.343134</td>
#       <td id="T_8fee2_row1_col1" class="data row1 col1" >38.014573</td>
#       <td id="T_8fee2_row1_col2" class="data row1 col2" >-85.635692</td>
#       <td id="T_8fee2_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_8fee2_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_8fee2_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_8fee2_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_8fee2_row1_col7" class="data row1 col7" >NO Fault</td>
#     </tr>
#     <tr>
#       <th id="T_8fee2_level0_row2" class="row_heading level0 row2" >9592</th>
#       <td id="T_8fee2_row2_col0" class="data row2 col0" >-9.643177</td>
#       <td id="T_8fee2_row2_col1" class="data row2 col1" >86.355034</td>
#       <td id="T_8fee2_row2_col2" class="data row2 col2" >-79.614608</td>
#       <td id="T_8fee2_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_8fee2_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_8fee2_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_8fee2_row2_col6" class="data row2 col6" >0</td>
#       <td id="T_8fee2_row2_col7" class="data row2 col7" >NO Fault</td>
#     </tr>
#     <tr>
#       <th id="T_8fee2_level0_row3" class="row_heading level0 row3" >8284</th>
#       <td id="T_8fee2_row3_col0" class="data row3 col0" >54.404554</td>
#       <td id="T_8fee2_row3_col1" class="data row3 col1" >-2.227411</td>
#       <td id="T_8fee2_row3_col2" class="data row3 col2" >-55.468704</td>
#       <td id="T_8fee2_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_8fee2_row3_col4" class="data row3 col4" >0</td>
#       <td id="T_8fee2_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_8fee2_row3_col6" class="data row3 col6" >0</td>
#       <td id="T_8fee2_row3_col7" class="data row3 col7" >NO Fault</td>
#     </tr>
#     <tr>
#       <th id="T_8fee2_level0_row4" class="row_heading level0 row4" >1805</th>
#       <td id="T_8fee2_row4_col0" class="data row4 col0" >25706.052890</td>
#       <td id="T_8fee2_row4_col1" class="data row4 col1" >-25711.296920</td>
#       <td id="T_8fee2_row4_col2" class="data row4 col2" >5.244034</td>
#       <td id="T_8fee2_row4_col3" class="data row4 col3" >1</td>
#       <td id="T_8fee2_row4_col4" class="data row4 col4" >1</td>
#       <td id="T_8fee2_row4_col5" class="data row4 col5" >1</td>
#       <td id="T_8fee2_row4_col6" class="data row4 col6" >1</td>
#       <td id="T_8fee2_row4_col7" class="data row4 col7" >Line A Line B Line C to Ground Fault</td>
#     </tr>
#     <tr>
#       <th id="T_8fee2_level0_row5" class="row_heading level0 row5" >1341</th>
#       <td id="T_8fee2_row5_col0" class="data row5 col0" >-10053.279250</td>
#       <td id="T_8fee2_row5_col1" class="data row5 col1" >-307.295726</td>
#       <td id="T_8fee2_row5_col2" class="data row5 col2" >26.516378</td>
#       <td id="T_8fee2_row5_col3" class="data row5 col3" >1</td>
#       <td id="T_8fee2_row5_col4" class="data row5 col4" >0</td>
#       <td id="T_8fee2_row5_col5" class="data row5 col5" >1</td>
#       <td id="T_8fee2_row5_col6" class="data row5 col6" >1</td>
#       <td id="T_8fee2_row5_col7" class="data row5 col7" >Line A Line B to Ground Fault</td>
#     </tr>
#     <tr>
#       <th id="T_8fee2_level0_row6" class="row_heading level0 row6" >6343</th>
#       <td id="T_8fee2_row6_col0" class="data row6 col0" >-194.142639</td>
#       <td id="T_8fee2_row6_col1" class="data row6 col1" >-666.227958</td>
#       <td id="T_8fee2_row6_col2" class="data row6 col2" >860.445676</td>
#       <td id="T_8fee2_row6_col3" class="data row6 col3" >1</td>
#       <td id="T_8fee2_row6_col4" class="data row6 col4" >1</td>
#       <td id="T_8fee2_row6_col5" class="data row6 col5" >1</td>
#       <td id="T_8fee2_row6_col6" class="data row6 col6" >1</td>
#       <td id="T_8fee2_row6_col7" class="data row6 col7" >Line A Line B Line C to Ground Fault</td>
#     </tr>
#     <tr>
#       <th id="T_8fee2_level0_row7" class="row_heading level0 row7" >5932</th>
#       <td id="T_8fee2_row7_col0" class="data row7 col0" >-781.623399</td>
#       <td id="T_8fee2_row7_col1" class="data row7 col1" >747.350681</td>
#       <td id="T_8fee2_row7_col2" class="data row7 col2" >36.300590</td>
#       <td id="T_8fee2_row7_col3" class="data row7 col3" >0</td>
#       <td id="T_8fee2_row7_col4" class="data row7 col4" >1</td>
#       <td id="T_8fee2_row7_col5" class="data row7 col5" >1</td>
#       <td id="T_8fee2_row7_col6" class="data row7 col6" >1</td>
#       <td id="T_8fee2_row7_col7" class="data row7 col7" >Line A Line B Line C</td>
#     </tr>
#     <tr>
#       <th id="T_8fee2_level0_row8" class="row_heading level0 row8" >8688</th>
#       <td id="T_8fee2_row8_col0" class="data row8 col0" >54.990832</td>
#       <td id="T_8fee2_row8_col1" class="data row8 col1" >-0.225791</td>
#       <td id="T_8fee2_row8_col2" class="data row8 col2" >-57.931253</t

# %%
df_class['Fault_Type'].value_counts(ascending=False)
# Out:
# Fault_Type
# NO Fault                                2617
# Line A to Ground Fault                  1271
# Line A Line B Line C to Ground Fault    1264
# Line A Line B to Ground Fault           1227
# Line A Line B Line C                    1202
# Line B to Line C Fault                  1118
# Line C to Ground Fault                   157
# Line B Fault                             145
# Line B to Ground Fault                   113
# Line A Line C to Ground Fault            110
# Line B Line C to Ground Fault            102
# Line A to Line C Fault                   101
# Line A Fault                             100
# Line C Fault                              98
# Line A to Line B fault                    95
# Name: count, dtype: int64

# %% [markdown]
# <h1 style="background-color:black
# ;font-family:newtimeroman;font-size:350%;text-align:center;border-radius: 150px 150px; color:#40E0D0">Feature and Label seperation </h1><a id=0></a>

# %% [markdown]
# <span style="background-color:pink;
#              color:Blue;
#              font-size:25px;
#              text-align:center;
#              border-radius:50px 80px;
#              font-weight:bold;
#              border:2px solid red;
#              padding:0px 20px;"> Categorical to Numerical conversion
# </span>

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
df_class['Fault_Type'] = encoder.fit_transform(df_class['Fault_Type'])
df_class.head()
# Out:
#          Ia         Ib         Ic  G  C  B  A  Fault_Type
# 0  0.096536  -3.626482   3.529946  0  0  0  0          14
# 1  0.244247  -5.771591   5.527344  0  0  0  0          14
# 2  0.457486  -7.902264   7.444778  0  0  0  0          14
# 3  0.734731 -10.017085   9.282354  0  0  0  0          14
# 4  1.074442 -12.114648  11.040206  0  0  0  0          14

# %% [markdown]
# <span style="background-color:pink;
#              color:Blue;
#              font-size:25px;
#              text-align:center;
#              border-radius:50px 80px;
#              font-weight:bold;
#              border:2px solid red;
#              padding:0px 20px;"> Dependent and Independent Variable Sepration
# </span>

# %%
X = df_class.drop(['Fault_Type'],axis=1)
y = df_class['Fault_Type']

# %% [markdown]
# <span style="background-color:pink;
#              color:Blue;
#              font-size:25px;
#              text-align:center;
#              border-radius:50px 80px;
#              font-weight:bold;
#              border:2px solid red;
#              padding:0px 20px;"> Train Test Split
# </span>

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=.20,random_state=21)

# %% [markdown]
# <h1 style="background-color:black
# ;font-family:newtimeroman;font-size:350%;text-align:center;border-radius: 150px 150px; color:#40E0D0"> Model Selection </h1><a id=0></a>

# %% [markdown]
# <div style="display:fill;
#             border-radius:15px;
#             background-color:cyan;
#             font-size:210%;
#             font-family:Vardana;
#             letter-spacing:0.5px;
#             padding:10px;
#             color:Brown;
#             border-style: solid;
#             border-color: red;
#             text-align:Left;">
# <b>Logistic Regression</b>
# </div>

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# Logistic Regression
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
y_pred_lr = logreg.predict(X_test)

log_train = round(logreg.score(X_train, y_train) * 100, 2)
log_accuracy = round(accuracy_score(y_pred_lr, y_test) * 100, 2)


print("Training Accuracy    :",log_train ,"%")
print("Model Accuracy Score :",log_accuracy ,"%")
print("\033[1m--------------------------------------------------------\033[0m")
print("Classification_Report: \n",classification_report(y_test,y_pred_lr))
print("\033[1m--------------------------------------------------------\033[0m")
# Out:
# Training Accuracy    : 64.71 %
# Model Accuracy Score : 63.63 %
# --------------------------------------------------------
# Classification_Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        19
#            1       0.83      0.02      0.04       245
#            2       0.30      1.00      0.46       266
#            3       0.90      0.82      0.86       240
#            4       0.00      0.00      0.00        19
#            5       1.00      1.00      1.00       245
#            6       1.00      0.15      0.26        20
#            7       1.00      0.25      0.40        24
#            8       0.00      0.00      0.00        27
#            9       0.42      0.26      0.32        19
#           10       1.00      0.03      0.06        32
#           11       0.00      0.00      0.00       232
#           12       0.00      0.00      0.00        15
#           13       0.00      0.00      0.00        32
#           14       0.89      1.00      0.94       509
#
#     accuracy                           0.64      1944
#    macro avg       0.49      0.30      0.29      1944
# weighted avg       0.66      0.64      0.56      1944
#
# --------------------------------------------------------

# %% [markdown]
# <div style="display:fill;
#             border-radius:15px;
#             background-color:cyan;
#             font-size:210%;
#             font-family:Vardana;
#             letter-spacing:0.5px;
#             padding:10px;
#             color:Brown;
#             border-style: solid;
#             border-color: red;
#             text-align:Left;">
# <b>Decision Tree Classifier</b>
# </div>

# %%
# Decision Tree
from sklearn.tree import DecisionTreeClassifier
decision = DecisionTreeClassifier()
decision.fit(X_train, y_train)
y_pred_dec = decision.predict(X_test)

decision_train = round(decision.score(X_train, y_train) * 100, 2)
decision_accuracy = round(accuracy_score(y_pred_dec, y_test) * 100, 2)

print("Training Accuracy    :",decision_train ,"%")
print("Model Accuracy Score :",decision_accuracy ,"%")
print("\033[1m--------------------------------------------------------\033[0m")
print("Classification_Report: \n",classification_report(y_test,y_pred_dec))
print("\033[1m--------------------------------------------------------\033[0m")
# Out:
# Training Accuracy    : 100.0 %
# Model Accuracy Score : 100.0 %
# --------------------------------------------------------
# Classification_Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00       245
#            2       1.00      1.00      1.00       266
#            3       1.00      1.00      1.00       240
#            4       1.00      1.00      1.00        19
#            5       1.00      1.00      1.00       245
#            6       1.00      1.00      1.00        20
#            7       1.00      1.00      1.00        24
#            8       1.00      1.00      1.00        27
#            9       1.00      1.00      1.00        19
#           10       1.00      1.00      1.00        32
#           11       1.00      1.00      1.00       232
#           12       1.00      1.00      1.00        15
#           13       1.00      1.00      1.00        32
#           14       1.00      1.00      1.00       509
#
#     accuracy                           1.00      1944
#    macro avg       1.00      1.00      1.00      1944
# weighted avg       1.00      1.00      1.00      1944
#
# --------------------------------------------------------

# %% [markdown]
# <div style="display:fill;
#             border-radius:15px;
#             background-color:cyan;
#             font-size:210%;
#             font-family:Vardana;
#             letter-spacing:0.5px;
#             padding:10px;
#             color:Brown;
#             border-style: solid;
#             border-color: red;
#             text-align:Left;">
# <b>Random Forest Classifier</b>
# </div>

# %%
# Random Forest
from sklearn.ensemble import RandomForestClassifier
random_forest = RandomForestClassifier(n_estimators=100)
random_forest.fit(X_train, y_train)
y_pred_rf = random_forest.predict(X_test)
random_forest.score(X_train, y_train)

random_forest_train = round(random_forest.score(X_train, y_train) * 100, 2)
random_forest_accuracy = round(accuracy_score(y_pred_rf, y_test) * 100, 2)

print("Training Accuracy    :",random_forest_train ,"%")
print("Model Accuracy Score :",random_forest_accuracy ,"%")
print("\033[1m--------------------------------------------------------\033[0m")
print("Classification_Report: \n",classification_report(y_test,y_pred_rf))
print("\033[1m--------------------------------------------------------\033[0m")
# Out:
# Training Accuracy    : 100.0 %
# Model Accuracy Score : 100.0 %
# --------------------------------------------------------
# Classification_Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      1.00      1.00       245
#            2       1.00      1.00      1.00       266
#            3       1.00      1.00      1.00       240
#            4       1.00      1.00      1.00        19
#            5       1.00      1.00      1.00       245
#            6       1.00      1.00      1.00        20
#            7       1.00      1.00      1.00        24
#            8       1.00      1.00      1.00        27
#            9       1.00      1.00      1.00        19
#           10       1.00      1.00      1.00        32
#           11       1.00      1.00      1.00       232
#           12       1.00      1.00      1.00        15
#           13       1.00      1.00      1.00        32
#           14       1.00      1.00      1.00       509
#
#     accuracy                           1.00      1944
#    macro avg       1.00      1.00      1.00      1944
# weighted avg       1.00      1.00      1.00      1944
#
# --------------------------------------------------------

# %% [markdown]
# <div style="display:fill;
#             border-radius:15px;
#             background-color:cyan;
#             font-size:210%;
#             font-family:Vardana;
#             letter-spacing:0.5px;
#             padding:10px;
#             color:Brown;
#             border-style: solid;
#             border-color: red;
#             text-align:Left;">
# <b>XGB Classifier</b>
# </div>

# %%
import xgboost as Xgb
xgb = Xgb.XGBClassifier()
xgb.fit(X_train,y_train)
y_pred_xgb = xgb.predict(X_test)
xgb.score(X_train, y_train)

xgb_train = round(xgb.score(X_train, y_train) * 100, 2)
xgb_accuracy = round(accuracy_score(y_pred_xgb, y_test) * 100, 2)

print("Training Accuracy    :",xgb_train ,"%")
print("Model Accuracy Score :",xgb_accuracy ,"%")
print("\033[1m--------------------------------------------------------\033[0m")
print("Classification_Report: \n",classification_report(y_test,y_pred_xgb))
print("\033[1m--------------------------------------------------------\033[0m")
# Out:
# Training Accuracy    : 100.0 %
# Model Accuracy Score : 99.95 %
# --------------------------------------------------------
# Classification_Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97        19
#            1       1.00      1.00      1.00       245
#            2       1.00      1.00      1.00       266
#            3       1.00      1.00      1.00       240
#            4       1.00      1.00      1.00        19
#            5       1.00      1.00      1.00       245
#            6       1.00      1.00      1.00        20
#            7       1.00      1.00      1.00        24
#            8       1.00      1.00      1.00        27
#            9       1.00      1.00      1.00        19
#           10       1.00      1.00      1.00        32
#           11       1.00      1.00      1.00       232
#           12       1.00      1.00      1.00        15
#           13       1.00      1.00      1.00        32
#           14       1.00      1.00      1.00       509
#
#     accuracy                           1.00      1944
#    macro avg       1.00      1.00      1.00      1944
# weighted avg       1.00      1.00      1.00      1944
#
# --------------------------------------------------------

# %% [markdown]
# <div style="display:fill;
#             border-radius:15px;
#             background-color:cyan;
#             font-size:210%;
#             font-family:Vardana;
#             letter-spacing:0.5px;
#             padding:10px;
#             color:Brown;
#             border-style: solid;
#             border-color: red;
#             text-align:Left;">
# <b>Support Vector Machines</b>
# </div>

# %%
# Support Vector Machines
from sklearn.svm import SVC
svc = SVC()
svc.fit(X_train, y_train)
y_pred_svc = svc.predict(X_test)

svc_train = round(svc.score(X_train, y_train) * 100, 2)
svc_accuracy = round(accuracy_score(y_pred_svc, y_test) * 100, 2)

print("Training Accuracy    :",svc_train ,"%")
print("Model Accuracy Score :",svc_accuracy ,"%")
print("\033[1m--------------------------------------------------------\033[0m")
print("Classification_Report: \n",classification_report(y_test,y_pred_svc))
print("\033[1m--------------------------------------------------------\033[0m")
# Out:
# Training Accuracy    : 40.51 %
# Model Accuracy Score : 39.35 %
# --------------------------------------------------------
# Classification_Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        19
#            1       0.28      0.23      0.25       245
#            2       0.29      0.09      0.14       266
#            3       0.49      0.38      0.42       240
#            4       0.57      0.63      0.60        19
#            5       0.18      0.01      0.02       245
#            6       1.00      0.45      0.62        20
#            7       1.00      0.29      0.45        24
#            8       0.00      0.00      0.00        27
#            9       0.65      0.58      0.61        19
#           10       0.71      0.53      0.61        32
#           11       0.89      0.03      0.07       232
#           12       0.00      0.00      0.00        15
#           13       0.70      0.59      0.64        32
#           14       0.38      1.00      0.55       509
#
#     accuracy                           0.39      1944
#    macro avg       0.48      0.32      0.33      1944
# weighted avg       0.42      0.39      0.30      1944
#
# --------------------------------------------------------

# %% [markdown]
# <h1 style="background-color:black
# ;font-family:newtimeroman;font-size:350%;text-align:center;border-radius: 150px 150px; color:#40E0D0"> Comparing Different Models </h1><a id=0></a>

# %%
models = pd.DataFrame({
    'Model': [
        'Support Vector Machines', 'Logistic Regression', 'Random Forest',
        'Decision Tree', 'XGBClassifier'
    ],

    'Training Accuracy':
    [log_train, svc_train, decision_train, random_forest_train, xgb_train],

    'Model Accuracy Score': [
        log_accuracy, svc_accuracy, decision_accuracy, random_forest_accuracy,
        xgb_accuracy
    ]
})

# %%
(models
 .sort_values(by='Model Accuracy Score', ascending=False)
 .style.background_gradient(cmap='coolwarm')
 .set_properties(**{
     'font-family': 'Lucida Calligraphy',
     'color': 'LightGreen',
     'font-size': '15px'
 })

)
# Out:
# <style type="text/css">
# #T_1ff48_row0_col0, #T_1ff48_row1_col0, #T_1ff48_row2_col0, #T_1ff48_row3_col0, #T_1ff48_row4_col0 {
#   font-family: Lucida Calligraphy;
#   color: LightGreen;
#   font-size: 15px;
# }
# #T_1ff48_row0_col1, #T_1ff48_row0_col2, #T_1ff48_row1_col1, #T_1ff48_row1_col2, #T_1ff48_row2_col1, #T_1ff48_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
#   font-family: Lucida Calligraphy;
#   color: LightGreen;
#   font-size: 15px;
# }
# #T_1ff48_row3_col1 {
#   background-color: #c3d5f4;
#   color: #000000;
#   font-family: Lucida Calligraphy;
#   color: LightGreen;
#   font-size: 15px;
# }
# #T_1ff48_row3_col2 {
#   background-color: #c0d4f5;
#   color: #000000;
#   font-family: Lucida Calligraphy;
#   color: LightGreen;
#   font-size: 15px;
# }
# #T_1ff48_row4_col1, #T_1ff48_row4_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
#   font-family: Lucida Calligraphy;
#   color: LightGreen;
#   font-size: 15px;
# }
# </style>
# <table id="T_1ff48" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1ff48_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1ff48_level0_col1" class="col_heading level0 col1" >Training Accuracy</th>
#       <th id="T_1ff48_level0_col2" class="col_heading level0 col2" >Model Accuracy Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1ff48_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_1ff48_row0_col0" class="data row0 col0" >Random Forest</td>
#       <td id="T_1ff48_row0_col1" class="data row0 col1" >100.000000</td>
#       <td id="T_1ff48_row0_col2" class="data row0 col2" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1ff48_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_1ff48_row1_col0" class="data row1 col0" >Decision Tree</td>
#       <td id="T_1ff48_row1_col1" class="data row1 col1" >100.000000</td>
#       <td id="T_1ff48_row1_col2" class="data row1 col2" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1ff48_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_1ff48_row2_col0" class="data row2 col0" >XGBClassifier</td>
#       <td id="T_1ff48_row2_col1" class="data row2 col1" >100.000000</td>
#       <td id="T_1ff48_row2_col2" class="data row2 col2" >99.950000</td>
#     </tr>
#     <tr>
#       <th id="T_1ff48_level0_row3" class="row_heading level0 row3" >0</th>
#       <td id="T_1ff48_row3_col0" class="data row3 col0" >Support Vector Machines</td>
#       <td id="T_1ff48_row3_col1" class="data row3 col1" >64.710000</td>
#       <td id="T_1ff48_row3_col2" class="data row3 col2" >63.630000</td>
#     </tr>
#     <tr>
#       <th id="T_1ff48_level0_row4" class="row_heading level0 row4" >1</th>
#       <td id="T_1ff48_row4_col0" class="data row4 col0" >Logistic Regression</td>
#       <td id="T_1ff48_row4_col1" class="data row4 col1" >40.510000</td>
#       <td id="T_1ff48_row4_col2" class="data row4 col2" >39.350000</td>
#     </tr>
#   </tbody>
# </table>

# %%
models=models.sort_values(by='Model Accuracy Score',ascending=False)[:8]

sns.barplot(y= 'Model', x= 'Model Accuracy Score', data= models)
plt.title('COMPARE THE MODEL')
plt.xlabel('MODEL')
plt.ylabel('Training Accuracy');

# %% [markdown]
# <h1 style="background-color:black
# ;font-family:newtimeroman;font-size:350%;text-align:center;border-radius: 150px 150px; color:#40E0D0"> Result Prediction</h1><a id=0></a>

# %% [markdown]
# <span style="background-color:yellow;
#              color:Black;
#              font-size:25px;
#              text-align:center;
#              border-radius:30px 80px;
#              font-weight:bold;
#              border:2px solid red;
#              padding:0px 20px;">1. Random Forest Classifier
# </span>

# %%
prediction1 = random_forest.predict(X_test)
print(prediction1)
# Out:
# [ 1 14 14 ...  3  2  3]

# %%
cross_checking = pd.DataFrame({'Actual' : y_test , 'Predicted' : prediction1})
cross_checking.sample(5).style.background_gradient(
        cmap='coolwarm').set_properties(**{
            'color': 'LigntGreen',
            'font-size': '15px'
        })
# Out:
# <style type="text/css">
# #T_aa91c_row0_col0, #T_aa91c_row0_col1, #T_aa91c_row4_col0, #T_aa91c_row4_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_aa91c_row1_col0, #T_aa91c_row1_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_aa91c_row2_col0, #T_aa91c_row2_col1 {
#   background-color: #c5d6f2;
#   color: #000000;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_aa91c_row3_col0, #T_aa91c_row3_col1 {
#   background-color: #f4987a;
#   color: #000000;
#   color: LigntGreen;
#   font-size: 15px;
# }
# </style>
# <table id="T_aa91c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aa91c_level0_col0" class="col_heading level0 col0" >Actual</th>
#       <th id="T_aa91c_level0_col1" class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aa91c_level0_row0" class="row_heading level0 row0" >8913</th>
#       <td id="T_aa91c_row0_col0" class="data row0 col0" >14</td>
#       <td id="T_aa91c_row0_col1" class="data row0 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_aa91c_level0_row1" class="row_heading level0 row1" >6817</th>
#       <td id="T_aa91c_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_aa91c_row1_col1" class="data row1 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_aa91c_level0_row2" class="row_heading level0 row2" >1104</th>
#       <td id="T_aa91c_row2_col0" class="data row2 col0" >7</td>
#       <td id="T_aa91c_row2_col1" class="data row2 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_aa91c_level0_row3" class="row_heading level0 row3" >1265</th>
#       <td id="T_aa91c_row3_col0" class="data row3 col0" >11</td>
#       <td id="T_aa91c_row3_col1" class="data row3 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_aa91c_level0_row4" class="row_heading level0 row4" >152</th>
#       <td id="T_aa91c_row4_col0" class="data row4 col0" >14</td>
#       <td id="T_aa91c_row4_col1" class="data row4 col1" >14</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <span style="background-color:yellow;
#              color:Black;
#              font-size:25px;
#              text-align:center;
#              border-radius:30px 80px;
#              font-weight:bold;
#              border:2px solid red;
#              padding:0px 20px;">2. Decision Tree Classifier
# </span>

# %%
prediction2 = decision.predict(X_test)
print(prediction2)
# Out:
# [ 1 14 14 ...  3  2  3]

# %%
cross_checking = pd.DataFrame({'Actual' : y_test , 'Predicted' : prediction2})
cross_checking.sample(5).style.background_gradient(
        cmap='coolwarm').set_properties(**{
            'color': 'LigntGreen',
            'font-size': '15px'
        })
# Out:
# <style type="text/css">
# #T_44d4a_row0_col0, #T_44d4a_row0_col1 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_44d4a_row1_col0, #T_44d4a_row1_col1, #T_44d4a_row2_col0, #T_44d4a_row2_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_44d4a_row3_col0, #T_44d4a_row3_col1 {
#   background-color: #e6d7cf;
#   color: #000000;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_44d4a_row4_col0, #T_44d4a_row4_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
#   color: LigntGreen;
#   font-size: 15px;
# }
# </style>
# <table id="T_44d4a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_44d4a_level0_col0" class="col_heading level0 col0" >Actual</th>
#       <th id="T_44d4a_level0_col1" class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_44d4a_level0_row0" class="row_heading level0 row0" >3463</th>
#       <td id="T_44d4a_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_44d4a_row0_col1" class="data row0 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_44d4a_level0_row1" class="row_heading level0 row1" >7651</th>
#       <td id="T_44d4a_row1_col0" class="data row1 col0" >14</td>
#       <td id="T_44d4a_row1_col1" class="data row1 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_44d4a_level0_row2" class="row_heading level0 row2" >8456</th>
#       <td id="T_44d4a_row2_col0" class="data row2 col0" >14</td>
#       <td id="T_44d4a_row2_col1" class="data row2 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_44d4a_level0_row3" class="row_heading level0 row3" >795</th>
#       <td id="T_44d4a_row3_col0" class="data row3 col0" >8</td>
#       <td id="T_44d4a_row3_col1" class="data row3 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_44d4a_level0_row4" class="row_heading level0 row4" >5813</th>
#       <td id="T_44d4a_row4_col0" class="data row4 col0" >1</td>
#       <td id="T_44d4a_row4_col1" class="data row4 col1" >1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <span style="background-color:yellow;
#              color:Black;
#              font-size:25px;
#              text-align:center;
#              border-radius:30px 80px;
#              font-weight:bold;
#              border:2px solid red;
#              padding:0px 20px;">3. XGB Classifier
# </span>

# %%
prediction3 = xgb.predict(X_test)
print(prediction3)
# Out:
# [ 1 14 14 ...  3  2  3]

# %%
cross_checking = pd.DataFrame({'Actual' : y_test , 'Predicted' : prediction3})
cross_checking.sample(5).style.background_gradient(
        cmap='coolwarm').set_properties(**{
            'color': 'LigntGreen',
            'font-size': '15px'
        })
# Out:
# <style type="text/css">
# #T_0777f_row0_col0, #T_0777f_row0_col1, #T_0777f_row3_col0, #T_0777f_row3_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_0777f_row1_col0, #T_0777f_row1_col1 {
#   background-color: #8db0fe;
#   color: #000000;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_0777f_row2_col0, #T_0777f_row2_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_0777f_row4_col0, #T_0777f_row4_col1 {
#   background-color: #f4987a;
#   color: #000000;
#   color: LigntGreen;
#   font-size: 15px;
# }
# </style>
# <table id="T_0777f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0777f_level0_col0" class="col_heading level0 col0" >Actual</th>
#       <th id="T_0777f_level0_col1" class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0777f_level0_row0" class="row_heading level0 row0" >7025</th>
#       <td id="T_0777f_row0_col0" class="data row0 col0" >2</td>
#       <td id="T_0777f_row0_col1" class="data row0 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_0777f_level0_row1" class="row_heading level0 row1" >2673</th>
#       <td id="T_0777f_row1_col0" class="data row1 col0" >5</td>
#       <td id="T_0777f_row1_col1" class="data row1 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_0777f_level0_row2" class="row_heading level0 row2" >7654</th>
#       <td id="T_0777f_row2_col0" class="data row2 col0" >14</td>
#       <td id="T_0777f_row2_col1" class="data row2 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_0777f_level0_row3" class="row_heading level0 row3" >6337</th>
#       <td id="T_0777f_row3_col0" class="data row3 col0" >2</td>
#       <td id="T_0777f_row3_col1" class="data row3 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_0777f_level0_row4" class="row_heading level0 row4" >4515</th>
#       <td id="T_0777f_row4_col0" class="data row4 col0" >11</td>
#       <td id="T_0777f_row4_col1" class="data row4 col1" >11</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <span style="background-color:yellow;
#              color:Black;
#              font-size:25px;
#              text-align:center;
#              border-radius:30px 80px;
#              font-weight:bold;
#              border:2px solid red;
#              padding:0px 20px;">4. Support Vector Machines
# </span>

# %%
prediction4 = svc.predict(X_test)
print(prediction4)
# Out:
# [ 1 14 14 ...  3 14  3]

# %%
cross_checking = pd.DataFrame({'Actual' : y_test , 'Predicted' : prediction4})
cross_checking.sample(5).style.background_gradient(
        cmap='coolwarm').set_properties(**{
            'color': 'LigntGreen',
            'font-size': '15px'
        })
# Out:
# <style type="text/css">
# #T_9c7bc_row0_col0, #T_9c7bc_row0_col1, #T_9c7bc_row2_col0, #T_9c7bc_row2_col1, #T_9c7bc_row3_col1, #T_9c7bc_row4_col0, #T_9c7bc_row4_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_9c7bc_row1_col0, #T_9c7bc_row1_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_9c7bc_row3_col0 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
#   color: LigntGreen;
#   font-size: 15px;
# }
# </style>
# <table id="T_9c7bc" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9c7bc_level0_col0" class="col_heading level0 col0" >Actual</th>
#       <th id="T_9c7bc_level0_col1" class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9c7bc_level0_row0" class="row_heading level0 row0" >8641</th>
#       <td id="T_9c7bc_row0_col0" class="data row0 col0" >14</td>
#       <td id="T_9c7bc_row0_col1" class="data row0 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_9c7bc_level0_row1" class="row_heading level0 row1" >6129</th>
#       <td id="T_9c7bc_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_9c7bc_row1_col1" class="data row1 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_9c7bc_level0_row2" class="row_heading level0 row2" >9478</th>
#       <td id="T_9c7bc_row2_col0" class="data row2 col0" >14</td>
#       <td id="T_9c7bc_row2_col1" class="data row2 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_9c7bc_level0_row3" class="row_heading level0 row3" >3491</th>
#       <td id="T_9c7bc_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_9c7bc_row3_col1" class="data row3 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_9c7bc_level0_row4" class="row_heading level0 row4" >7957</th>
#       <td id="T_9c7bc_row4_col0" class="data row4 col0" >14</td>
#       <td id="T_9c7bc_row4_col1" class="data row4 col1" >14</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <span style="background-color:yellow;
#              color:Black;
#              font-size:25px;
#              text-align:center;
#              border-radius:30px 80px;
#              font-weight:bold;
#              border:2px solid red;
#              padding:0px 20px;">5. Logistic Regression
# </span>

# %%
prediction5 = logreg.predict(X_test)
print(prediction5)
# Out:
# [ 2 14 14 ...  3  2  3]

# %%
cross_checking = pd.DataFrame({'Actual' : y_test , 'Predicted' : prediction5})
cross_checking.sample(5).style.background_gradient(
        cmap='coolwarm').set_properties(**{
            'font-family': 'Lucida Calligraphy',
            'color': 'LigntGreen',
            'font-size': '15px'
        })
# Out:
# <style type="text/css">
# #T_6e09e_row0_col0, #T_6e09e_row0_col1, #T_6e09e_row1_col1, #T_6e09e_row4_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6e09e_row1_col0 {
#   background-color: #f4987a;
#   color: #000000;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6e09e_row2_col0, #T_6e09e_row2_col1 {
#   background-color: #8db0fe;
#   color: #000000;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6e09e_row3_col0, #T_6e09e_row3_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# #T_6e09e_row4_col0 {
#   background-color: #5470de;
#   color: #f1f1f1;
#   font-family: Lucida Calligraphy;
#   color: LigntGreen;
#   font-size: 15px;
# }
# </style>
# <table id="T_6e09e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6e09e_level0_col0" class="col_heading level0 col0" >Actual</th>
#       <th id="T_6e09e_level0_col1" class="col_heading level0 col1" >Predicted</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6e09e_level0_row0" class="row_heading level0 row0" >7345</th>
#       <td id="T_6e09e_row0_col0" class="data row0 col0" >2</td>
#       <td id="T_6e09e_row0_col1" class="data row0 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_6e09e_level0_row1" class="row_heading level0 row1" >4253</th>
#       <td id="T_6e09e_row1_col0" class="data row1 col0" >11</td>
#       <td id="T_6e09e_row1_col1" class="data row1 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_6e09e_level0_row2" class="row_heading level0 row2" >2767</th>
#       <td id="T_6e09e_row2_col0" class="data row2 col0" >5</td>
#       <td id="T_6e09e_row2_col1" class="data row2 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_6e09e_level0_row3" class="row_heading level0 row3" >8470</th>
#       <td id="T_6e09e_row3_col0" class="data row3 col0" >14</td>
#       <td id="T_6e09e_row3_col1" class="data row3 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_6e09e_level0_row4" class="row_heading level0 row4" >3705</th>
#       <td id="T_6e09e_row4_col0" class="data row4 col0" >3</td>
#       <td id="T_6e09e_row4_col1" class="data row4 col1" >2</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div style="color:white;
#        display:fill;
#        border-radius:5px;
#        background-color:yellow;
#        font-size:120%;
#        font-family:Nexa;
#        style:justify;
#        font-family:'Times New Roman';
#        letter-spacing:0.5px">
#     <p style="padding: 10px;
#           color:Black;">
#          Random Forest,Decision Tree Classifier,XGB Classifier,	are giving the best Result with 100 percent accuracy and  is doing  a great job till now in Fault Detection, than the rest of the models because it's able to predict all the signals in most efficient manner while in other models there are cases where there is actually fault but the model is not able to identify it.Logistic Regression is giving the worst accuracy
#     </p>
# </div>
