# %% [markdown]
# <a href="https://colab.research.google.com/github/marwan229/Data_Science-project/blob/main/Untitled29.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing necessary packages
import pandas as pd
import numpy as np
import sklearn
from sklearn import linear_model
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score,f1_score
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.svm import LinearSVC,SVC
from sklearn.neighbors import KNeighborsClassifier

# %%
def data_loader(file_path):

    df = pd.read_csv(file_path)

    display(df)
    print()

    shape = df.shape
    display(shape)
    print()

    display('Missing Values:')
    missing_values = df.isnull().sum()
    display(missing_values)
    print()

    display('Data Types:')
    data_types = df.dtypes
    display(data_types)
    print()

    return df, shape, missing_values, data_types

# %%
data_loader('/content/class.csv')
print()
data_loader('/content/target.csv')
# Out:
#              Ia         Ib         Ic  G  C  B  A
# 0      0.096536  -3.626482   3.529946  0  0  0  0
# 1      0.244247  -5.771591   5.527344  0  0  0  0
# 2      0.457486  -7.902264   7.444778  0  0  0  0
# 3      0.734731 -10.017085   9.282354  0  0  0  0
# 4      1.074442 -12.114648  11.040206  0  0  0  0
# ...         ...        ...        ... .. .. .. ..
# 9715 -66.237921  38.457041  24.912239  0  0  0  0
# 9716 -65.849493  37.465454  25.515675  0  0  0  0
# 9717 -65.446698  36.472055  26.106554  0  0  0  0
# 9718 -65.029633  35.477088  26.684731  0  0  0  0
# 9719 -64.598401  34.480799  27.250065  0  0  0  0
#
# [9720 rows x 7 columns]
# (9720, 7)
# 'Missing Values:'
# Ia    0
# Ib    0
# Ic    0
# G     0
# C     0
# B     0
# A     0
# dtype: int64
# 'Data Types:'
# Ia    float64
# Ib    float64
# Ic    float64
# G       int64
# C       int64
# B       int64
# A       int64
# dtype: object
#               Ia         Ib         Ic  Fault_Type
# ...

# %%
detect = pd.read_csv('/content/target.csv')
class_data = pd.read_csv('/content/class.csv')



display('Detect', detect.isnull().sum())
display('Class', class_data.isnull().sum())
# Out:
# 'Detect'
# Ia            0
# Ib            0
# Ic            0
# Fault_Type    0
# dtype: int64
# 'Class'
# Ia    0
# Ib    0
# Ic    0
# G     0
# C     0
# B     0
# A     0
# dtype: int64

# %%
df= pd.read_csv("/content/target.csv")

# %%
def data_tester(df):
    display(df)
    print()

    shape = df.shape
    display(shape)
    print()

    display('Missing Values:')
    missing_values = df.isnull().sum()
    display(missing_values)
    print()

    display('Data Types:')
    data_types = df.dtypes
    display(data_types)
    print()

    return df, shape, missing_values, data_types

# %%
data_tester(df)
# Out:
#               Ia         Ib         Ic  Fault_Type
# 0       0.096536  -3.626482   3.529946           0
# 1       0.244247  -5.771591   5.527344           0
# 2       0.457486  -7.902264   7.444778           0
# 3       0.734731 -10.017085   9.282354           0
# 4       1.074442 -12.114648  11.040206           0
# ...          ...        ...        ...         ...
# 14463 -66.237921  38.457041  24.912239           0
# 14464 -65.849493  37.465454  25.515675           0
# 14465 -65.446698  36.472055  26.106554           0
# 14466 -65.029633  35.477088  26.684731           0
# 14467 -64.598401  34.480799  27.250065           0
#
# [14468 rows x 4 columns]
# (14468, 4)
# 'Missing Values:'
# Ia            0
# Ib            0
# Ic            0
# Fault_Type    0
# dtype: int64
# 'Data Types:'
# Ia            float64
# Ib            float64
# Ic            float64
# Fault_Type      int64
# dtype: object
# (              Ia         Ib         Ic  Fault_Type
# ...

# %%
# Define the filenames of datasets
d_dataset = 'target.csv'
c_dataset = 'class.csv'

# Define the features and target columns
features = ['Ia', 'Ib', 'Ic',]
targets = ['G', 'C', 'B', 'A']

# Initialize lists to store accuracy and error data
detect_accuracy = []
detect_error = []
class_accuracy = []
class_error = []

# Function to import datasets
def import_data(filepath):
    return pd.read_csv(filepath).dropna(axis=1)

# Importing the data
detection_train = import_data(d_dataset)
class_train = import_data(c_dataset)

# Defining the inputs and outputs
detection_data_X = detection_train[features]
class_data_X = class_train[features]
detection_data_Y = detection_train['Fault_']
class_data_Y = class_train[targets]

# Splitting the data
class_train_X, class_test_X, class_train_Y, class_test_Y = train_test_split(
    class_data_X, class_data_Y, test_size=0.33, random_state=1
)
detection_train_X, detection_test_X, detection_train_Y, detection_test_Y = train_test_split(
    detection_data_X, detection_data_Y, test_size=0.33, random_state=1
)

# %%
# !pip install lazypredict

# %%
from lazypredict.Supervised import LazyClassifier
# Define the filenames of datasets
d_dataset = 'target.csv'
c_dataset = 'class.csv'

# Define the features and target columns
features = ['Ia', 'Ib', 'Ic']
detect_target = 'Fault_Type'
class_targets = ['G', 'C', 'B', 'A']

# Function to import datasets
def import_data(filepath):
    return pd.read_csv(filepath).dropna()

# Importing the data
detection_train = import_data(d_dataset)
class_train = import_data(c_dataset)

# Defining the inputs and outputs
detection_data_X = detection_train[features]
class_data_X = class_train[features]
detection_data_Y = detection_train[detect_target]

# Splitting the data
detection_train_X, detection_test_X, detection_train_Y, detection_test_Y = train_test_split(
    detection_data_X, detection_data_Y, test_size=0.33, random_state=42
)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Lasso, LinearRegression
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ***Decision Trees***

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Fault Detection Model:
# Instantiate the DecisionTreeClassifier object
# Fit the model to the training data
# Predict on the test data
# Calculate the accuracy of the model
detection_model = DecisionTreeClassifier(random_state=1)

detection_model.fit(detection_train_X, detection_train_Y)

detection_predictions = detection_model.predict(detection_test_X)

detection_accuracy = accuracy_score(detection_test_Y, detection_predictions)


# Fault Classification Model:
# Instantiate the DecisionTreeClassifier object
# Fit the model to the training data
# Predict on the test data
# Calculate the accuracy of the model
classification_model = DecisionTreeClassifier(random_state=1)

classification_model.fit(class_train_X, class_train_Y)

classification_predictions = classification_model.predict(class_test_X)

classification_accuracy = accuracy_score(class_test_Y, classification_predictions)


print("Fault Detection Model Accuracy: ", detection_accuracy)
print("Fault Detection Model Classification Report: ")
print(classification_report(detection_test_Y, detection_predictions))
print("Fault Detection Model Confusion Matrix: ")
print(confusion_matrix(detection_test_Y, detection_predictions))

print("\nFault Classification Model Accuracy: ", classification_accuracy)
print("Fault Classification Model Classification Report: ")
print(classification_report(class_test_Y, classification_predictions))
print("Fault Classification Model Confusion Matrix: ")
print(confusion_matrix(class_test_Y, classification_predictions))
# Out:
# Fault Detection Model Accuracy:  0.9719371727748691
# Fault Detection Model Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97      2398
#            1       0.98      0.96      0.97      2377
#
#     accuracy                           0.97      4775
#    macro avg       0.97      0.97      0.97      4775
# weighted avg       0.97      0.97      0.97      4775
#
# Fault Detection Model Confusion Matrix:
# [[2350   48]
#  [  86 2291]]
#
# Fault Classification Model Accuracy:  0.8559850374064838
# Fault Classification Model Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.88      0.87      1815
#            1       0.84      0.82      0.83      1393
#
#     accuracy                           0.86      3208
#    macro avg       0.85      0.85      0.85      3208
# weighted avg       0.86      0.86      0.86      3208
#
# ...

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# Visualizing the detection model
plt.figure(figsize=(20, 10))
plot_tree(detection_model, filled=True, rounded=True, feature_names=detection_train_X.columns)
plt.title('Fault Detection Model')
plt.show()

# Visualizing the classification model
plt.figure(figsize=(20, 10))
plot_tree(classification_model, filled=True, rounded=True, feature_names=class_train_X.columns)
plt.title('Fault Classification Model')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier

# Function to plot the accuracy versus alpha for training and testing sets
def plot_accuracy_vs_alpha(ccp_alphas, train_scores, test_scores):
    fig, ax = plt.subplots()
    ax.set_xlabel("alpha")
    ax.set_ylabel("accuracy")
    ax.set_title("Accuracy vs alpha for training and testing sets")
    ax.plot(ccp_alphas, train_scores, marker='o', label="train",
            drawstyle="steps-post")
    ax.plot(ccp_alphas, test_scores, marker='o', label="test",
            drawstyle="steps-post")
    ax.legend()
    plt.show()

def apply_ccp(X_train, y_train, X_test, y_test):
    clf = DecisionTreeClassifier(random_state=0)
    path = clf.cost_complexity_pruning_path(X_train, y_train)
    ccp_alphas = path.ccp_alphas
    ccp_alphas = ccp_alphas[:-1]  # Exclude the maximum value of alpha which is for the root only.

    clfs = []
    for ccp_alpha in ccp_alphas:
        clf = DecisionTreeClassifier(random_state=0, ccp_alpha=ccp_alpha)
        clf.fit(X_train, y_train)
        clfs.append(clf)

    train_scores = [clf.score(X_train, y_train) for clf in clfs]
    test_scores = [clf.score(X_test, y_test) for clf in clfs]

    plot_accuracy_vs_alpha(ccp_alphas, train_scores, test_scores)

    # Get the maximum test score and the corresponding alpha value
    max_test_score = max(test_scores)
    max_alpha = ccp_alphas[test_scores.index(max_test_score)]

    print("Test Scores: ", test_scores)
    print("Max Test Score: ", max_test_score)
    print("Alpha for Max Test Score: ", max_alpha)


# Apply cost complexity pruning for the Fault Detection Model
print("Fault Detection Model")
apply_ccp(detection_train_X, detection_train_Y, detection_test_X, detection_test_Y)

# Apply cost complexity pruning for the Fault Classification Model
print("Fault Classification Model")
apply_ccp(class_train_X, class_train_Y, class_test_X, class_test_Y)
# Out:
# Fault Detection Model
# ...

# %% [markdown]
# ***Random Forest***

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, classification_report
# Fault Detection Model
detection_forest = RandomForestClassifier(random_state=1)
detection_forest.fit(detection_train_X, detection_train_Y)

# Fault Classification Model
classification_forest = RandomForestClassifier(random_state=1)
classification_forest.fit(class_train_X, class_train_Y)


# Fault Detection Model
detection_predictions = detection_forest.predict(detection_test_X)
detection_accuracy = accuracy_score(detection_test_Y, detection_predictions)

print("Fault Detection Model Accuracy: ", detection_accuracy)
print("Fault Detection Model Classification Report: ")
print(classification_report(detection_test_Y, detection_predictions))

# Fault Classification Model
classification_predictions = classification_forest.predict(class_test_X)
classification_accuracy = accuracy_score(class_test_Y, classification_predictions)

print("\nFault Classification Model Accuracy: ", classification_accuracy)
print("Fault Classification Model Classification Report: ")
print(classification_report(class_test_Y, classification_predictions))

# Visualizing one tree from the detection forest
plt.figure(figsize=(20, 10))
tree = detection_forest.estimators_[0]  # Arbitrary Selection from the forest
plot_tree(tree, filled=True, rounded=True, feature_names=detection_train_X.columns)
plt.title('One Tree from the Fault Detection Forest')
plt.show()

# Visualizing one tree from the classification forest
plt.figure(figsize=(20, 10))
tree = classification_forest.estimators_[0]  # Arbitrary Selection from the forest
plot_tree(tree, filled=True, rounded=True, feature_names=class_train_X.columns)
plt.title('One Tree from the Fault Classification Forest')
plt.show()
# Out:
# Fault Detection Model Accuracy:  0.974869109947644
# Fault Detection Model Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98      2398
#            1       0.99      0.96      0.97      2377
#
#     accuracy                           0.97      4775
#    macro avg       0.98      0.97      0.97      4775
# weighted avg       0.98      0.97      0.97      4775
#
#
# Fault Classification Model Accuracy:  0.8581670822942643
# Fault Classification Model Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.87      0.87      1815
#            1       0.83      0.84      0.84      1393
#
#     accuracy                           0.86      3208
#    macro avg       0.86      0.86      0.86      3208
# weighted avg       0.86      0.86      0.86      3208

# %% [markdown]
# **Fault Detection CNN Model**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout
from sklearn.preprocessing import MinMaxScaler

from sklearn.model_selection import GridSearchCV

# %%
df1 = pd.read_csv('target.csv')

# %%
print ('Number of Samples:', df.shape[0])
print ('Number of Columns:', df.shape[1])
# Out:
# Number of Samples: 14468
# Number of Columns: 4

# %%
print ('Number of Patients with outcome 0:', df.shape[0] - df1.Fault_Type.sum())
print ('Number of Patients with outcome 1:', df1.Fault_Type.sum())
# Out:
# Number of Patients with outcome 0: 7365
# Number of Patients with outcome 1: 7103

# %%
from sklearn.model_selection import train_test_split

X = df.drop(columns="Fault_Type")
Y = df[["Fault_Type"]]

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
print (f'Shape of train data: {X_train.shape}')
print (f'Shape of test data: {X_test.shape}')
# Out:
# Shape of train data: (11574, 3)
# Shape of test data: (2894, 3)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
model = Sequential([
    Dense(24, input_dim=df.shape[1]-1, activation='relu', name='hidden_1'),
    Dense(12, activation='relu', name='hidden_2'),
    Dense(1, activation='sigmoid', name='output'),
])

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  hidden_1 (Dense)            (None, 24)                96
#
#  hidden_2 (Dense)            (None, 12)                300
#
#  output (Dense)              (None, 1)                 13
#
# ...
# Total params: 409 (1.60 KB)
# Trainable params: 409 (1.60 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Out:
# Epoch 1/100
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-2146a9110ba6> in <cell line: 1>()
# ----> 1 history = model.fit(X_train, y_train, epochs=100, batch_size=16, verbose=1)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in tf__train_function(iterator)
#      13                 try:
#      14                     do_return = True
# ...

# %%
# Defining and Reshaping the input data for the CNN model
detection_train_X = detection_train_X.reshape(-1, 3, 1, 1)
detection_test_X = detection_test_X.reshape(-1, 3, 1, 1)  # Correct approach

model = Sequential()
model.add(Conv2D(32, kernel_size=(2, 1), activation='relu', input_shape=(3, 1, 1)))
model.add(MaxPooling2D(pool_size=(2, 1)))
model.add(Flatten())
model.add(Dense(1, activation='sigmoid'))

# Compile the model (binary_crossentropy and adam based on the nature of detection)
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Trainning the model
model.fit(detection_train_X, detection_train_Y, epochs=100, batch_size=32, validation_data=(detection_test_X, detection_test_Y))

# Evaluating the model
score = model.evaluate(detection_test_X, detection_test_Y)
print('Test accuracy:', score[1])

# Making arbutrary predictions on new data
new_data = np.array([[-0.5, 0.5, -0.5, 0.5, -0.5, 0.5]])
new_data = new_data.reshape(-1, 3, 1, 1)
prediction = model.predict(new_data)
print('Prediction:', prediction)
# Out:
# Epoch 1/100
# 303/303 [==============================] - 3s 5ms/step - loss: 34.5618 - accuracy: 0.4751 - val_loss: 5.9901 - val_accuracy: 0.5198
# Epoch 2/100
# 303/303 [==============================] - 1s 3ms/step - loss: 3.8128 - accuracy: 0.5925 - val_loss: 1.6043 - val_accuracy: 0.6913
# Epoch 3/100
# 303/303 [==============================] - 1s 3ms/step - loss: 0.5719 - accuracy: 0.8316 - val_loss: 0.2096 - val_accuracy: 0.9401
# Epoch 4/100
# 303/303 [==============================] - 1s 2ms/step - loss: 0.2031 - accuracy: 0.9487 - val_loss: 0.1985 - val_accuracy: 0.9487
# Epoch 5/100
# 303/303 [==============================] - 1s 3ms/step - loss: 0.1949 - accuracy: 0.9521 - val_loss: 0.1950 - val_accuracy: 0.9516
# Epoch 6/100
# 303/303 [==============================] - 1s 2ms/step - loss: 0.1921 - accuracy: 0.9522 - val_loss: 0.1928 - val_accuracy: 0.9527
# Epoch 7/100
# ...

# %%
# Normalizing the data
scaler = MinMaxScaler()
detection_train_X = scaler.fit_transform(detection_train_X)
detection_train_X = detection_train_X.reshape(detection_train_X.shape[0], detection_train_X.shape[1], 1)

detection_test_X = scaler.transform(detection_test_X)
detection_test_X = detection_test_X.reshape(detection_test_X.shape[0], detection_test_X.shape[1], 1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-27c9d322b9c5> in <cell line: 3>()
#       1 # Normalizing the data
#       2 scaler = MinMaxScaler()
# ----> 3 detection_train_X = scaler.fit_transform(detection_train_X)
#       4 detection_train_X = detection_train_X.reshape(detection_train_X.shape[0], detection_train_X.shape[1], 1)
#       5
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     138     @wraps(f)
#     139     def wrapped(self, X, *args, **kwargs):
# --> 140         data_to_wrap = f(self, X, *args, **kwargs)
#     141         if isinstance(data_to_wrap, tuple):
#     142             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     876         if y is None:
# ...
